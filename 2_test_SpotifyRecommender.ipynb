# %% [markdown]
# # KNN - Model

# %%
import pandas as pd
import numpy as np
import pickle
import time
import os
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.neighbors import NearestNeighbors


class SpotifyRecommender:
    supported = ['acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 'valence'] + [f'Chroma_{i}' for i in range(1, 13)] + [f'MEL_{i}' for i in range(1, 129)] + [f'MFCC_{i}' for i in range(1, 49)] + [f'Spectral_contrast_{i}' for i in range(1, 8)] + [f'Tonnetz_{i}' for i in range(1, 7)] + ['ZCR', 'entropy_energy', 'spectral_bandwith', 'spectral_centroid', 'spectral_rollOff_max', 'spectral_rollOff_min']
    return_columns = ['name','artists_name','artists_genres','album_name','track_href','preview_url','analysis_url','href','lyrics','playlist','popularity','tempo','time_signature','track_id',
             'artists_followers', 'artists_artist_popularity', 'artists_id','album_release_date','album_images','album_total_tracks','album_external_urls','album_id']
    def __init__(self,load_model="",k=300):
        self.scaler = None
        self.pca = None
        self.sfm = None
        self.knn = None
        self.k = k
        self.filepath = 'saved_modelV2.pkl'
        self.dataset = None
        self.trained_features = []
        if not load_model == "":
            path = os.path.join(load_model)
            self.load(path)
        

    def __get_features(self,data,features):
        listed = data.columns.tolist()
        for f in listed:
            if f in self.supported and f in features:
                self.trained_features.append(f)
        return
    
    def __match_genre(self, row, target_list):
        target_words = set(word for genre in target_list for word in genre.split(' '))
        row_words = set(word for genre in row for word in genre.split(' '))
        return len(row_words.intersection(target_words))


    def train(self,dataset,n_lines=0,features=supported):
        self.__get_features(dataset,features)
        self.dataset = dataset

        if not n_lines == 0:
            dataset = dataset.sample(n=n_lines)

        self.scaler = StandardScaler()
        scaled_data = self.scaler.fit_transform(dataset[self.trained_features])

        rf = RandomForestRegressor(n_estimators=100, random_state=42)
        rf.fit(scaled_data, dataset.index)  # Hier verwende ich data.index anstelle von target

        self.sfm = SelectFromModel(rf, threshold='mean')
        self.sfm.fit(scaled_data, dataset.index)  # Hier verwende ich data.index anstelle von target

        self.pca = PCA(n_components=0.95)
        reduced_data = self.pca.fit_transform(scaled_data[:, self.sfm.get_support()])

        self.knn = NearestNeighbors(n_neighbors=self.k)
        self.knn.fit(reduced_data)

    def predict(self, df_selected,k=None,match_genre=True):
        if not k==None:
            self.knn.n_neighbors = k

        new_scaled_data = self.scaler.transform(df_selected[self.trained_features])
        new_reduced_data = self.pca.transform(new_scaled_data[:, self.sfm.get_support()])
        distances, indices = self.knn.kneighbors(new_reduced_data)
        
        self.knn.n_neighbors = self.k
        result = self.dataset[self.return_columns].iloc[indices[0]]
        result['distances'] = distances[0]

        result = result.sort_values('album_release_date', ascending=False)
        result = result.drop_duplicates(subset=['name', 'artists_name'], keep='first')

        if match_genre:
            result['match_genre_count'] = result['artists_genres'].apply(self.__match_genre, target_list=df_selected['artists_genres'].tolist()[0])
            return result.sort_values(by=['match_genre_count','distances'], ascending=[False,True])
        else:
            return result.sort_values(by='distances',ascending=True)

    def save(self, file_path=None):
        if file_path == None:
            file_path = self.filepath
        model_data = {
            'knn': self.knn,
            'scaler': self.scaler,
            'pca': self.pca,
            'sfm': self.sfm,
            'dataset': self.dataset,
            'filepath': file_path,
            'trained_features': self.trained_features
        }
        with open(file_path, 'wb') as f:
            pickle.dump(model_data, f)

    def load(self, file_path):
        with open(file_path, 'rb') as f:
            model_data = pickle.load(f)

        self.knn = model_data['knn']
        self.scaler = model_data['scaler']
        self.pca = model_data['pca']
        self.sfm = model_data['sfm']
        self.filepath = model_data['filepath']
        self.trained_features =  model_data['trained_features']
        self.dataset = model_data['dataset']

# %% [markdown]
# # ETL - Prozess

# %%
import os
import pandas as pd
import ast

# @op
def str_to_list(s):
    s = str(s)[1:-1]
    if len(s) == 0:
        s = "'not defined'"
    items = s.split(',')
    return [item.replace("'","") for item in items]

# @asset
def import_albums():
    albums_path = os.path.join('spotify_data/Data Sources/spotify_albums.csv')
    return pd.read_csv(albums_path,sep=',',index_col='Unnamed: 0').rename(columns=lambda x: "album_" + x)

# @asset
def import_artists():
    albums_path = os.path.join('spotify_data/Data Sources/spotify_artists.csv')
    return pd.read_csv(albums_path,sep=',',index_col='Unnamed: 0').rename(columns=lambda x: "artists_" + x)

# @asset
def import_tracks():
    albums_path = os.path.join('spotify_data/Data Sources/spotify_tracks.csv')
    return pd.read_csv(albums_path,sep=',',index_col='Unnamed: 0').rename(columns={'id':'track_id','artists_id':'track_artists_id'})

# @asset
def import_lyrics_features():
    albums_path = os.path.join('spotify_data/Features Extracted/lyrics_features.csv')
    df = pd.read_csv(albums_path,sep=',',index_col='Unnamed: 0')
    return df

# @asset
def import_audio_features():
    albums_path = os.path.join('spotify_data/Features Extracted/low_level_audio_features.csv')
    df = pd.read_csv(albums_path,sep=',',index_col='Unnamed: 0')
    return df

# @op
def transform_albums(albums_raw):
    df = albums_raw.copy()
    df['album_available_markets'] = df['album_available_markets'].apply(lambda x: str_to_list(x))
    df['album_release_date'] = pd.to_datetime(df['album_release_date'])
    df['album_external_urls'] = df['album_external_urls'].apply(ast.literal_eval)
    df['album_images'] = df['album_images'].apply(ast.literal_eval)
    
    return df

# @op
def transform_artists(artists_raw):
    df = artists_raw.copy()
    df['artists_genres'] = df['artists_genres'].apply(lambda x: str_to_list(x))

    return df

# @op
def transform_tracks(tracks_raw):
    df = tracks_raw.copy()
    df['available_markets'] = df['available_markets'].apply(lambda x: str_to_list(x))
    df['track_artists_id'] = df['track_artists_id'].apply(lambda x: str_to_list(x))

    return df

# @op
def match_spotify_data(tracks,albums,artists,audio_features,lyrics_features):
    tracks = tracks.explode('track_artists_id') # tack zeile pro artist

    merged = pd.merge(tracks, albums, left_on='album_id', right_on='album_id', how='inner')
    tracks_albums_artists = pd.merge(merged, artists, left_on='track_artists_id', right_on='artists_id', how='inner')
    # inner -> 101939 rows × 53 columns

    tracks_albums_artists_audio = pd.merge(tracks_albums_artists, audio_features, left_on='track_id', right_on='track_id', how='inner')
    tracks_albums_artists_audio_lyrics = pd.merge(tracks_albums_artists_audio, lyrics_features, left_on='track_id', right_on='track_id', how='inner')
    # inner -> 94924 rows × 266 columns

    return tracks_albums_artists_audio_lyrics

# @op
def train_model(df,n_lines,features,filename):
    model = SpotifyRecommender()
    if features == None:
        model.train(df, n_lines)
    else:
        model.train(df, n_lines, features)
    model.save(filename)

# @job
def create_full_model():
    raw_albums = import_albums()
    raw_artists = import_artists()
    raw_tracks = import_tracks()
    raw_lyrics_features = import_lyrics_features()
    raw_audio_features = import_audio_features()

    albums = transform_albums(raw_albums)
    artists = transform_artists(raw_artists)
    tracks = transform_tracks(raw_tracks)
    lyrics_features = raw_lyrics_features
    audio_features = raw_audio_features
    
    df = match_spotify_data(tracks,albums,artists,audio_features,lyrics_features)
    
    train_model(df,0,None,"SpotifyRecommender_allFeatures.pkl")


# @job
def create_apiFeatures_model():
    features = ['acousticness', 'danceability', 'duration_ms', 
                'energy', 'instrumentalness', 'key', 'liveness', 
                'loudness', 'mode', 'speechiness', 'tempo', 
                'time_signature','valence']
    raw_albums = import_albums()
    raw_artists = import_artists()
    raw_tracks = import_tracks()
    raw_lyrics_features = import_lyrics_features()
    raw_audio_features = import_audio_features()

    albums = transform_albums(raw_albums)
    artists = transform_artists(raw_artists)
    tracks = transform_tracks(raw_tracks)
    lyrics_features = raw_lyrics_features
    audio_features = raw_audio_features
    
    df = match_spotify_data(tracks,albums,artists,audio_features,lyrics_features)
    
    train_model(df,0,features,'SpotifyRecommender_apiFeatures.pkl')

# %% [markdown]
# # Modell mit allen Featurs erstellen

# %%
create_full_model() # ca. 2h

# %%
model=SpotifyRecommender()
# model.load('SpotifyRecommender_allFeatures.pkl')
model.load('models/SpotifyRecommender_allFeatures.pkl')

# %%
track_id = '0EYOdF5FCkgOJJla8DI2Md'
data_for_prediction = model.dataset[model.dataset['track_id']==track_id]

# %%
output = model.predict(data_for_prediction,k=40,match_genre=True)
output.head(10)
# Out:
#                           name      artists_name  \
# 700                   B.Y.O.B.  System Of A Down
# 45142            Falling Apart        Papa Roach
# 25517  State of Love and Trust         Pearl Jam
# 89242                 One Word      Baby Animals
# 72880           Two Doors Down      Mystery Jets
# 55117                Awakening   Throw The Fight
# 45131          Drowned in Gold      Boston Manor
# 40314               The Sinner  Memphis May Fire
# 80807    Alone in the Universe   The Motorleague
# 92958                   Nostos     Orion's Reign
#
#                                           artists_genres  \
# 700    [alternative metal,  nu metal,  post-grunge,  ...
# 45142  [alternative metal,  nu metal,  pop punk,  pos...
# 25517  [alternative rock,  grunge,  permanent wave,  ...
# 89242  [australian alternative rock,  australian pop,...
# 72880  [alternative dance,  british indie rock,  danc...
# 55117  [christian rock,  gymcore,  hard alternative, ...
# 45131       [alternative emo,  anthem emo,  uk pop punk]
# 40314  [christian rock,  melodic metalcore,  metalcor...
# 80807              [canadian rock,  new brunswick indie]
# 92958              [greek metal,  symphonic power metal]
#
#                                              album_name  \
# 700                                           Mezmerize
# 45142                                          F.E.A.R.
# 25517          rearviewmirror (greatest hits 1991-2003)
# 89242  Baby Animals - 25th Anniversary (Deluxe Edition)
# 72880                                        Twenty One
# 55117                                         Awakening
# 45131                                   Drowned in Gold
# 40314                                        The Hollow
# 80807                             Alone in the Universe
# 92958                                            Nostos
#
#                                               track_href  \
# 700    https://api.spotify.com/v1/tracks/0EYOdF5FCkgO...
# 45142  https://api.spotify.com/v1/tracks/1Ka4sX789wNf...
# 25517  https://api.spotify.com/v1/tracks/6dnmovOCP7vG...
# 89242  https://api.spotify.com/v1/tracks/7MKtgvzqOjyZ...
# 72880  https://api.spotify.com/v1/tracks/5JSF5Nhw9W6j...
# 55117  https://api.spotify.com/v1/tracks/4EmokJEqiyqI...
# 45131  https://api.spotify.com/v1/tracks/4t7xcd1KMNzx...
# 40314  https://api.spotify.com/v1/tracks/4SAeLRKTvdvE...
# 80807  https://api.spotify.com/v1/tracks/03luhU2VQd1j...
# 92958  https://api.spotify.com/v1/tracks/3W6Xik6Xxf06...
#
#                                              preview_url  \
# 700    https://p.scdn.co/mp3-preview/2f373f029e1110b1...
# 45142  https://p.scdn.co/mp3-preview/52b4d4d3966ffc77...
# 25517  https://p.scdn.co/mp3-preview/4c532a394fd3764b...
# 89242  https://p.scdn.co/mp3-preview/5bc898b0759c167d...
# 72880  https://p.scdn.co/mp3-preview/a017fd07956d9cc7...
# 55117  https://p.scdn.co/mp3-preview/3a99df675b2a2164...
# 45131  https://p.scdn.co/mp3-preview/eed280559725cd2b...
# 40314  https://p.scdn.co/mp3-preview/61c72645899a3d66...
# 80807  https://p.scdn.co/mp3-preview/a5986d301049623a...
# 92958  https://p.scdn.co/mp3-preview/6faa83d912975f76...
#
#                                             analysis_url  \
# 700    https://api.spotify.com/v1/audio-analysis/0EYO...
# 45142  https://api.spotify.com/v1/audio-analysis/1Ka4...
# 25517  https://api.spotify.com/v1/audio-analysis/6dnm...
# 89242  https://api.spotify.com/v1/audio-analysis/7MKt...
# 72880  https://api.spotify.com/v1/audio-analysis/5JSF...
# 55117  https://api.spotify.com/v1/audio-analysis/4Emo...
# 45131  https://api.spotify.com/v1/audio-analysis/4t7x...
# 40314  https://api.spotify.com/v1/audio-analysis/4SAe...
# 80807  https://api.spotify.com/v1/audio-analysis/03lu...
# 92958  https://api.spotify.com/v1/audio-analysis/3W6X...
#
#                                                     href  \
# 700    https://api.spotify.com/v1/tracks/0EYOdF5FCkgO...
# 45142  https://api.spotify.com/v1/tracks/1Ka4sX789wNf...
# 25517  https://api.spotify.com/v1/tracks/6dnmovOCP7vG...
# 89242  https://api.spotify.com/v1/tracks/7MKtgvzqOjyZ...
# 72880  https://api.spotify.com/v1/tracks/5JSF5Nhw9W6j...
# 55117  https://api.spotify.com/v1/tracks/4EmokJEqiyqI...
# 45131  https://api.spotify.com/v1/tracks/4t7xcd1KMNzx...
# 40314  https://api.spotify.com/v1/tracks/4SAeLRKTvdvE...
# 80807  https://api.spotify.com/v1/tracks/03luhU2VQd1j...
# 92958  https://api.spotify.com/v1/tracks/3W6Xik6Xxf06...
#
#                                                   lyrics  \
# 700    \r\n\r\nYou!\r\nWhy do they always send the po...
# 45142  \r\n\r\nI'll follow you out of the dark\r\nI t...
# 25517  \r\nState of love and trust as I busted down t...
# 89242  \r\nOh I wake up feeling the same way every da...
# 72880  \r\n\r\nI think I'm in love with the girl next...
# 55117  \r\nI'll follow you into the dark\r\nI'll be t...
# 45131  \r\n\r\nChoose love, choose tears\r\nChoose bu...
# 40314  \r\n\r\nDigging a hole that I can't get out of...
# 80807  \r\n          \r\n            Lyrics for this ...
# 92958  \r\nThe night is falling in silence\r\nWaking ...
#
#                                playlist  ...  artists_followers  \
# 700                    Metal Essentials  ...            4774393
# 45142                    Pegando Pesado  ...            2527961
# 25517  1990-luvun alternative ja grunge  ...            4400511
# 89242                 90s Workout Beats  ...              47330
# 72880                     Indie Workout  ...             108665
# 55117                         Rock Hard  ...              18203
# 45131               Rock Save the Queen  ...              51093
# 40314                       Heavy Gamer  ...             416798
# 80807                     Ready to Rock  ...               2267
# 92958                    Epic & Melodic  ...               2050
#
#        artists_artist_popularity              artists_id album_release_date  \
# 700                           79  5eAWCfyUhZtHHtBdNk56l1         2005-05-17
# 45142                         76  4RddZ3iHvSpGV4dvATac9X         2015-01-27
# 25517                         78  1w5Kfo2jwwIPruYS2UWh56         2004-11-16
# 89242                         44  2DaDoR6WXStRctDQDWWQpI         1991-05-20
# 72880                         51  09K1H1DgyIXHsMx2j7KTFX         2008-03-21
# 55117                         49  1nRfyHvAh1foLjOCa3hbv7         2019-01-11
# 45131                         52  4WjeQi9wm84lYTIWZ95QoM         2017-12-05
# 40314                         60  7cNNNhdJDrt3vgQjwSavNf         2011-04-25
# 80807                         32  0mMfUMeFxdsH5ijLeGYPdc         2018-11-02
# 92958                         34  3hRL14TJtJqr7i1IH3D1pU         2018-10-05
#
#                                             album_images  album_total_tracks  \
# 700    [{'height': 640, 'url': 'https://i.scdn.co/ima...                  11
# 45142  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  12
# 25517  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  33
# 89242  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  28
# 72880  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  11
# 55117  [{'height': 640, 'url': 'https://i.scdn.co/ima...                   1
# 45131  [{'height': 640, 'url': 'https://i.scdn.co/ima...                   1
# 40314  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  10
# 80807  [{'height': 640, 'url': 'https://i.scdn.co/ima...                   1
# 92958  [{'height': 600, 'url': 'https://i.scdn.co/ima...                   1
#
#                                      album_external_urls  \
# 700    {'spotify': 'https://open.spotify.com/album/0c...
# 45142  {'spotify': 'https://open.spotify.com/album/70...
# 25517  {'spotify': 'https://open.spotify.com/album/1G...
# 89242  {'spotify': 'https://open.spotify.com/album/2i...
# 72880  {'spotify': 'https://open.spotify.com/album/2e...
# 55117  {'spotify': 'https://open.spotify.com/album/56...
# 45131  {'spotify': 'https://open.spotify.com/album/1R...
# 40314  {'spotify': 'https://open.spotify.com/album/59...
# 80807  {'spotify': 'https://open.spotify.com/album/6c...
# 92958  {'spotify': 'https://open.spotify.com/album/2Z...
#
#                      album_id distances  match_genre_count
# 700    0cn6MHyx4YuZauaB7Pb66o  0.000000                  7
# 45142  70TYHf7Is70KOY1sHl5Vlh  7.544761                  7
# 25517  1G1R5dY01DSyti3NaWnOp3  7.677549                  4
# 89242  2iwQHQZ2a2eyNjuQmfSdJI  8.082564                  3
# 72880  2efbbdHh1iSps9yfBZdy7G  8.116682                  3
# 55117  563WVcixzFSli4vAEm3Qxr  8.164526                  3
# 45131  1RYorhaHUvSf1vwYnUdoVt  7.495476                  2
# 40314  59fpw1PC2LgFYS0Hmn4zm3  7.653596                  2
# 80807  6cHMgyMhNtDYWgdR5imrBg  7.716357                  2
# 92958  2ZNyqng4E2LUSI2iDA4o04  8.036067                  2
#
# [10 rows x 24 columns]

# %%
data_for_prediction['artists_genres'].tolist()[0]
# Out:
# ['alternative metal', ' nu metal', ' post-grunge', ' rap metal', ' rock']

# %%
def match_count(row, target_list):
    return len(set(row).intersection(target_list))


output['match_count'] = output['artists_genres'].apply(match_count, target_list=data_for_prediction['artists_genres'].tolist()[0])
output.sort_values('match_count', ascending=False).head(10)
# Out:
#                                                     name  \
# 700                                             B.Y.O.B.
# 45142                                      Falling Apart
# 25517                            State of Love and Trust
# 30716                                         Headstrong
# 5992                                            Paranoia
# 32683                                 You Are Everything
# 55348                                        Now / Never
# 16609                                 A Mirage of Safety
# 8095   Can You Hear Me? (ayayaya) - feat. Skepta, JME...
# 27802                                     Ivy (Doomsday)
#
#                  artists_name  \
# 700          System Of A Down
# 45142              Papa Roach
# 25517               Pearl Jam
# 30716                 Saviour
# 5992        A Day To Remember
# 32683         Holding Absence
# 55348  She Pulled the Trigger
# 16609                    Mute
# 8095                    Wiley
# 27802    The Amity Affliction
#
#                                           artists_genres  \
# 700    [alternative metal,  nu metal,  post-grunge,  ...
# 45142  [alternative metal,  nu metal,  pop punk,  pos...
# 25517  [alternative rock,  grunge,  permanent wave,  ...
# 30716                         [australian post-hardcore]
# 5992                    [metalcore,  pop punk,  screamo]
# 32683                     [melodic hardcore,  metalcore]
# 55348                           [gymcore,  post-screamo]
# 16609  [fast melodic punk,  melodic hardcore,  quebec...
# 8095            [grime,  house,  uk garage,  uk hip hop]
# 27802          [melodic metalcore,  metalcore,  screamo]
#
#                                       album_name  \
# 700                                    Mezmerize
# 45142                                   F.E.A.R.
# 25517   rearviewmirror (greatest hits 1991-2003)
# 30716                                 Headstrong
# 5992             Bad Vibrations (Deluxe Edition)
# 32683                            Holding Absence
# 55348                             No Matter What
# 16609                             Remember Death
# 8095   Can You Hear Me? (ft. Skepta, JME & Ms D)
# 27802                             Ivy (Doomsday)
#
#                                               track_href  \
# 700    https://api.spotify.com/v1/tracks/0EYOdF5FCkgO...
# 45142  https://api.spotify.com/v1/tracks/1Ka4sX789wNf...
# 25517  https://api.spotify.com/v1/tracks/6dnmovOCP7vG...
# 30716  https://api.spotify.com/v1/tracks/0exunPxmEEME...
# 5992   https://api.spotify.com/v1/tracks/3HhaSocKwTpt...
# 32683  https://api.spotify.com/v1/tracks/6RJSpUgLZ46a...
# 55348  https://api.spotify.com/v1/tracks/1962zHkiWIAV...
# 16609  https://api.spotify.com/v1/tracks/7bvrzWzYGld7...
# 8095   https://api.spotify.com/v1/tracks/40gQwsrLW23q...
# 27802  https://api.spotify.com/v1/tracks/51VHAM1iIiki...
#
#                                              preview_url  \
# 700    https://p.scdn.co/mp3-preview/2f373f029e1110b1...
# 45142  https://p.scdn.co/mp3-preview/52b4d4d3966ffc77...
# 25517  https://p.scdn.co/mp3-preview/4c532a394fd3764b...
# 30716  https://p.scdn.co/mp3-preview/b92a175b7efc4437...
# 5992   https://p.scdn.co/mp3-preview/69c620e40a904eec...
# 32683  https://p.scdn.co/mp3-preview/2c3eae5ade97857a...
# 55348  https://p.scdn.co/mp3-preview/cd282bf9d64fb6c9...
# 16609  https://p.scdn.co/mp3-preview/1161acb237f6f2ef...
# 8095   https://p.scdn.co/mp3-preview/e8e4645e79a5cab3...
# 27802  https://p.scdn.co/mp3-preview/03ca5bc9bef62f29...
#
#                                             analysis_url  \
# 700    https://api.spotify.com/v1/audio-analysis/0EYO...
# 45142  https://api.spotify.com/v1/audio-analysis/1Ka4...
# 25517  https://api.spotify.com/v1/audio-analysis/6dnm...
# 30716  https://api.spotify.com/v1/audio-analysis/0exu...
# 5992   https://api.spotify.com/v1/audio-analysis/3Hha...
# 32683  https://api.spotify.com/v1/audio-analysis/6RJS...
# 55348  https://api.spotify.com/v1/audio-analysis/1962...
# 16609  https://api.spotify.com/v1/audio-analysis/7bvr...
# 8095   https://api.spotify.com/v1/audio-analysis/40gQ...
# 27802  https://api.spotify.com/v1/audio-analysis/51VH...
#
#                                                     href  \
# 700    https://api.spotify.com/v1/tracks/0EYOdF5FCkgO...
# 45142  https://api.spotify.com/v1/tracks/1Ka4sX789wNf...
# 25517  https://api.spotify.com/v1/tracks/6dnmovOCP7vG...
# 30716  https://api.spotify.com/v1/tracks/0exunPxmEEME...
# 5992   https://api.spotify.com/v1/tracks/3HhaSocKwTpt...
# 32683  https://api.spotify.com/v1/tracks/6RJSpUgLZ46a...
# 55348  https://api.spotify.com/v1/tracks/1962zHkiWIAV...
# 16609  https://api.spotify.com/v1/tracks/7bvrzWzYGld7...
# 8095   https://api.spotify.com/v1/tracks/40gQwsrLW23q...
# 27802  https://api.spotify.com/v1/tracks/51VHAM1iIiki...
#
#                                                   lyrics  \
# 700    \r\n\r\nYou!\r\nWhy do they always send the po...
# 45142  \r\n\r\nI'll follow you out of the dark\r\nI t...
# 25517  \r\nState of love and trust as I busted down t...
# 30716  \r\nYou can only be headstrong\r\nFor so long\...
# 5992   \r\n\r\nExpect the worst of everyone I meet\r\...
# 32683  \r\n\r\nSome kind of doubt poisons my mind\r\n...
# 55348  \r\n\r\nHave you heard the news, my friend?\r\...
# 16609  \r\nIt’s finally over it’s something real\r\nB...
# 8095   \r\n\r\nI was on a path to the limelight\r\nNo...
# 27802  \r\n\r\nI will cover you like ivy\r\nAnd choke...
#
#                                playlist  ...  artists_artist_popularity  \
# 700                    Metal Essentials  ...                         79
# 45142                    Pegando Pesado  ...                         76
# 25517  1990-luvun alternative ja grunge  ...                         78
# 30716                 Homegrown + Heavy  ...                         38
# 5992                          Rage Quit  ...                         72
# 32683                      Crash Course  ...                         46
# 55348                      Crash Course  ...                         25
# 16609                        Skate Park  ...                         33
# 8095    The Brit Pack - Urban Graduates  ...                         67
# 27802                      Crash Course  ...                         65
#
#                    artists_id  album_release_date  \
# 700    5eAWCfyUhZtHHtBdNk56l1          2005-05-17
# 45142  4RddZ3iHvSpGV4dvATac9X          2015-01-27
# 25517  1w5Kfo2jwwIPruYS2UWh56          2004-11-16
# 30716  6xVW2xsoMQbvcUTwqYxf0y          2018-04-02
# 5992   4NiJW4q9ichVqL1aUsgGAN          2016-09-02
# 32683  2tl280wIokrLjabzrSKTgU          2019-03-01
# 55348  6u8zncAVE7R0ezzTOrBIZt          2018-06-22
# 16609  3hLIsgoNbqdaXgPZDF8Xfs          2016-10-14
# 8095   7k9T7lZlHjRAM1bb0r9Rm3          2012-10-19
# 27802  6kNKUYGn6VNGsRoXmyoDPK          2018-06-20
#
#                                             album_images  album_total_tracks  \
# 700    [{'height': 640, 'url': 'https://i.scdn.co/ima...                  11
# 45142  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  12
# 25517  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  33
# 30716  [{'height': 640, 'url': 'https://i.scdn.co/ima...                   1
# 5992   [{'height': 640, 'url': 'https://i.scdn.co/ima...                  13
# 32683  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  11
# 55348  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  12
# 16609  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  11
# 8095   [{'height': 640, 'url': 'https://i.scdn.co/ima...                   5
# 27802  [{'height': 640, 'url': 'https://i.scdn.co/ima...                   1
#
#                                      album_external_urls  \
# 700    {'spotify': 'https://open.spotify.com/album/0c...
# 45142  {'spotify': 'https://open.spotify.com/album/70...
# 25517  {'spotify': 'https://open.spotify.com/album/1G...
# 30716  {'spotify': 'https://open.spotify.com/album/6s...
# 5992   {'spotify': 'https://open.spotify.com/album/5r...
# 32683  {'spotify': 'https://open.spotify.com/album/6x...
# 55348  {'spotify': 'https://open.spotify.com/album/2V...
# 16609  {'spotify': 'https://open.spotify.com/album/5t...
# 8095   {'spotify': 'https://open.spotify.com/album/3R...
# 27802  {'spotify': 'https://open.spotify.com/album/6b...
#
#                      album_id distances match_count  match_substring_count
# 700    0cn6MHyx4YuZauaB7Pb66o  0.000000           5                      7
# 45142  70TYHf7Is70KOY1sHl5Vlh  7.544761           4                      7
# 25517  1G1R5dY01DSyti3NaWnOp3  7.677549           2                      4
# 30716  6s96bvTJTTp76rklucRK4I  7.036965           0                      0
# 5992   5rSgMFmmuaKQxma4bSEviU  8.141161           0                      1
# 32683  6xEQWs9XbaJBGAy4Jv7piM  8.147830           0                      1
# 55348  2VP7A4w7nnSvJe7z3A9x7j  7.178737           0                      1
# 16609  5tZjhfVEPlzlpD5nIxo8S3  7.892173           0                      1
# 8095   3RXrZMSIhU3UOg0cxjIICQ  8.026504           0                      1
# 27802  6bBnxNu9qGVxpGpbLcVjHr  8.095072           0                      1
#
# [10 rows x 25 columns]

# %%
def match_substring_count(row, target_list):
    target_words = set(word for genre in target_list for word in genre.split(' '))
    row_words = set(word for genre in row for word in genre.split(' '))
    return len(row_words.intersection(target_words))

output['match_substring_count'] = output['artists_genres'].apply(match_substring_count, target_list=data_for_prediction['artists_genres'].tolist()[0])


output = output.sort_values(by=['match_substring_count','distances'], ascending=[False,True])
output.head(10)
# Out:
#                           name      artists_name  \
# 700                   B.Y.O.B.  System Of A Down
# 45142            Falling Apart        Papa Roach
# 25517  State of Love and Trust         Pearl Jam
# 89242                 One Word      Baby Animals
# 72880           Two Doors Down      Mystery Jets
# 55117                Awakening   Throw The Fight
# 45131          Drowned in Gold      Boston Manor
# 40314               The Sinner  Memphis May Fire
# 80807    Alone in the Universe   The Motorleague
# 92958                   Nostos     Orion's Reign
#
#                                           artists_genres  \
# 700    [alternative metal,  nu metal,  post-grunge,  ...
# 45142  [alternative metal,  nu metal,  pop punk,  pos...
# 25517  [alternative rock,  grunge,  permanent wave,  ...
# 89242  [australian alternative rock,  australian pop,...
# 72880  [alternative dance,  british indie rock,  danc...
# 55117  [christian rock,  gymcore,  hard alternative, ...
# 45131       [alternative emo,  anthem emo,  uk pop punk]
# 40314  [christian rock,  melodic metalcore,  metalcor...
# 80807              [canadian rock,  new brunswick indie]
# 92958              [greek metal,  symphonic power metal]
#
#                                              album_name  \
# 700                                           Mezmerize
# 45142                                          F.E.A.R.
# 25517          rearviewmirror (greatest hits 1991-2003)
# 89242  Baby Animals - 25th Anniversary (Deluxe Edition)
# 72880                                        Twenty One
# 55117                                         Awakening
# 45131                                   Drowned in Gold
# 40314                                        The Hollow
# 80807                             Alone in the Universe
# 92958                                            Nostos
#
#                                               track_href  \
# 700    https://api.spotify.com/v1/tracks/0EYOdF5FCkgO...
# 45142  https://api.spotify.com/v1/tracks/1Ka4sX789wNf...
# 25517  https://api.spotify.com/v1/tracks/6dnmovOCP7vG...
# 89242  https://api.spotify.com/v1/tracks/7MKtgvzqOjyZ...
# 72880  https://api.spotify.com/v1/tracks/5JSF5Nhw9W6j...
# 55117  https://api.spotify.com/v1/tracks/4EmokJEqiyqI...
# 45131  https://api.spotify.com/v1/tracks/4t7xcd1KMNzx...
# 40314  https://api.spotify.com/v1/tracks/4SAeLRKTvdvE...
# 80807  https://api.spotify.com/v1/tracks/03luhU2VQd1j...
# 92958  https://api.spotify.com/v1/tracks/3W6Xik6Xxf06...
#
#                                              preview_url  \
# 700    https://p.scdn.co/mp3-preview/2f373f029e1110b1...
# 45142  https://p.scdn.co/mp3-preview/52b4d4d3966ffc77...
# 25517  https://p.scdn.co/mp3-preview/4c532a394fd3764b...
# 89242  https://p.scdn.co/mp3-preview/5bc898b0759c167d...
# 72880  https://p.scdn.co/mp3-preview/a017fd07956d9cc7...
# 55117  https://p.scdn.co/mp3-preview/3a99df675b2a2164...
# 45131  https://p.scdn.co/mp3-preview/eed280559725cd2b...
# 40314  https://p.scdn.co/mp3-preview/61c72645899a3d66...
# 80807  https://p.scdn.co/mp3-preview/a5986d301049623a...
# 92958  https://p.scdn.co/mp3-preview/6faa83d912975f76...
#
#                                             analysis_url  \
# 700    https://api.spotify.com/v1/audio-analysis/0EYO...
# 45142  https://api.spotify.com/v1/audio-analysis/1Ka4...
# 25517  https://api.spotify.com/v1/audio-analysis/6dnm...
# 89242  https://api.spotify.com/v1/audio-analysis/7MKt...
# 72880  https://api.spotify.com/v1/audio-analysis/5JSF...
# 55117  https://api.spotify.com/v1/audio-analysis/4Emo...
# 45131  https://api.spotify.com/v1/audio-analysis/4t7x...
# 40314  https://api.spotify.com/v1/audio-analysis/4SAe...
# 80807  https://api.spotify.com/v1/audio-analysis/03lu...
# 92958  https://api.spotify.com/v1/audio-analysis/3W6X...
#
#                                                     href  \
# 700    https://api.spotify.com/v1/tracks/0EYOdF5FCkgO...
# 45142  https://api.spotify.com/v1/tracks/1Ka4sX789wNf...
# 25517  https://api.spotify.com/v1/tracks/6dnmovOCP7vG...
# 89242  https://api.spotify.com/v1/tracks/7MKtgvzqOjyZ...
# 72880  https://api.spotify.com/v1/tracks/5JSF5Nhw9W6j...
# 55117  https://api.spotify.com/v1/tracks/4EmokJEqiyqI...
# 45131  https://api.spotify.com/v1/tracks/4t7xcd1KMNzx...
# 40314  https://api.spotify.com/v1/tracks/4SAeLRKTvdvE...
# 80807  https://api.spotify.com/v1/tracks/03luhU2VQd1j...
# 92958  https://api.spotify.com/v1/tracks/3W6Xik6Xxf06...
#
#                                                   lyrics  \
# 700    \r\n\r\nYou!\r\nWhy do they always send the po...
# 45142  \r\n\r\nI'll follow you out of the dark\r\nI t...
# 25517  \r\nState of love and trust as I busted down t...
# 89242  \r\nOh I wake up feeling the same way every da...
# 72880  \r\n\r\nI think I'm in love with the girl next...
# 55117  \r\nI'll follow you into the dark\r\nI'll be t...
# 45131  \r\n\r\nChoose love, choose tears\r\nChoose bu...
# 40314  \r\n\r\nDigging a hole that I can't get out of...
# 80807  \r\n          \r\n            Lyrics for this ...
# 92958  \r\nThe night is falling in silence\r\nWaking ...
#
#                                playlist  ...  artists_artist_popularity  \
# 700                    Metal Essentials  ...                         79
# 45142                    Pegando Pesado  ...                         76
# 25517  1990-luvun alternative ja grunge  ...                         78
# 89242                 90s Workout Beats  ...                         44
# 72880                     Indie Workout  ...                         51
# 55117                         Rock Hard  ...                         49
# 45131               Rock Save the Queen  ...                         52
# 40314                       Heavy Gamer  ...                         60
# 80807                     Ready to Rock  ...                         32
# 92958                    Epic & Melodic  ...                         34
#
#                    artists_id  album_release_date  \
# 700    5eAWCfyUhZtHHtBdNk56l1          2005-05-17
# 45142  4RddZ3iHvSpGV4dvATac9X          2015-01-27
# 25517  1w5Kfo2jwwIPruYS2UWh56          2004-11-16
# 89242  2DaDoR6WXStRctDQDWWQpI          1991-05-20
# 72880  09K1H1DgyIXHsMx2j7KTFX          2008-03-21
# 55117  1nRfyHvAh1foLjOCa3hbv7          2019-01-11
# 45131  4WjeQi9wm84lYTIWZ95QoM          2017-12-05
# 40314  7cNNNhdJDrt3vgQjwSavNf          2011-04-25
# 80807  0mMfUMeFxdsH5ijLeGYPdc          2018-11-02
# 92958  3hRL14TJtJqr7i1IH3D1pU          2018-10-05
#
#                                             album_images  album_total_tracks  \
# 700    [{'height': 640, 'url': 'https://i.scdn.co/ima...                  11
# 45142  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  12
# 25517  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  33
# 89242  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  28
# 72880  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  11
# 55117  [{'height': 640, 'url': 'https://i.scdn.co/ima...                   1
# 45131  [{'height': 640, 'url': 'https://i.scdn.co/ima...                   1
# 40314  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  10
# 80807  [{'height': 640, 'url': 'https://i.scdn.co/ima...                   1
# 92958  [{'height': 600, 'url': 'https://i.scdn.co/ima...                   1
#
#                                      album_external_urls  \
# 700    {'spotify': 'https://open.spotify.com/album/0c...
# 45142  {'spotify': 'https://open.spotify.com/album/70...
# 25517  {'spotify': 'https://open.spotify.com/album/1G...
# 89242  {'spotify': 'https://open.spotify.com/album/2i...
# 72880  {'spotify': 'https://open.spotify.com/album/2e...
# 55117  {'spotify': 'https://open.spotify.com/album/56...
# 45131  {'spotify': 'https://open.spotify.com/album/1R...
# 40314  {'spotify': 'https://open.spotify.com/album/59...
# 80807  {'spotify': 'https://open.spotify.com/album/6c...
# 92958  {'spotify': 'https://open.spotify.com/album/2Z...
#
#                      album_id distances match_count  match_substring_count
# 700    0cn6MHyx4YuZauaB7Pb66o  0.000000           5                      7
# 45142  70TYHf7Is70KOY1sHl5Vlh  7.544761           4                      7
# 25517  1G1R5dY01DSyti3NaWnOp3  7.677549           2                      4
# 89242  2iwQHQZ2a2eyNjuQmfSdJI  8.082564           0                      3
# 72880  2efbbdHh1iSps9yfBZdy7G  8.116682           0                      3
# 55117  563WVcixzFSli4vAEm3Qxr  8.164526           0                      3
# 45131  1RYorhaHUvSf1vwYnUdoVt  7.495476           0                      2
# 40314  59fpw1PC2LgFYS0Hmn4zm3  7.653596           0                      2
# 80807  6cHMgyMhNtDYWgdR5imrBg  7.716357           0                      2
# 92958  2ZNyqng4E2LUSI2iDA4o04  8.036067           0                      2
#
# [10 rows x 25 columns]

# %% [markdown]
# # Modell mit den Haupt-Features
#
# apiFeature sind nur features, die aus der Spotify API als audio_features abgerufen werden können

# %%
create_apiFeatures_model() # ca 6 min

# %%
model=SpotifyRecommender()
model.load('SpotifyRecommender_apiFeatures.pkl')
# model.load('models/SpotifyRecommender_apiFeatures.pkl')

# %%
track_id = '0EYOdF5FCkgOJJla8DI2Md'
data_for_prediction = model.dataset[model.dataset['track_id']==track_id]
data_for_prediction[model.return_columns]
# Out:
#          name      artists_name  \
# 700  B.Y.O.B.  System Of A Down
#
#                                         artists_genres album_name  \
# 700  [alternative metal,  nu metal,  post-grunge,  ...  Mezmerize
#
#                                             track_href  \
# 700  https://api.spotify.com/v1/tracks/0EYOdF5FCkgO...
#
#                                            preview_url  \
# 700  https://p.scdn.co/mp3-preview/2f373f029e1110b1...
#
#                                           analysis_url  \
# 700  https://api.spotify.com/v1/audio-analysis/0EYO...
#
#                                                   href  \
# 700  https://api.spotify.com/v1/tracks/0EYOdF5FCkgO...
#
#                                                 lyrics          playlist  ...  \
# 700  \r\n\r\nYou!\r\nWhy do they always send the po...  Metal Essentials  ...
#
#      time_signature                track_id  artists_followers  \
# 700             4.0  0EYOdF5FCkgOJJla8DI2Md            4774393
#
#     artists_artist_popularity              artists_id  album_release_date  \
# 700                        79  5eAWCfyUhZtHHtBdNk56l1          2005-05-17
#
#                                           album_images album_total_tracks  \
# 700  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 11
#
#                                    album_external_urls                album_id
# 700  {'spotify': 'https://open.spotify.com/album/0c...  0cn6MHyx4YuZauaB7Pb66o
#
# [1 rows x 22 columns]

# %%
output = model.predict(data_for_prediction,k=40,match_genre=True)
output.head(10)
# Out:
#                               name      artists_name  \
# 700                       B.Y.O.B.  System Of A Down
# 43778                       Happy?          Mudvayne
# 722                   Be Legendary          Pop Evil
# 26161                      No More         Disturbed
# 26150               Open Your Eyes         Disturbed
# 26166            Land Of Confusion         Disturbed
# 17079  All My Friends are Nobodies         zebrahead
# 69641           T Minus Everything       Rabbit Junk
# 40283                 Dr. Feelgood       Mötley Crüe
# 31808                 Compartilhar        Oficina G3
#
#                                           artists_genres  \
# 700    [alternative metal,  nu metal,  post-grunge,  ...
# 43778  [alternative metal,  groove metal,  industrial...
# 722    [alternative metal,  nu metal,  post-grunge,  ...
# 26161  [alternative metal,  nu metal,  post-grunge,  ...
# 26150  [alternative metal,  nu metal,  post-grunge,  ...
# 26166  [alternative metal,  nu metal,  post-grunge,  ...
# 17079  [funk metal,  nu metal,  pop punk,  punk,  rap...
# 69641  [cyberpunk,  digital hardcore,  industrial met...
# 40283  [album rock,  classic rock,  glam metal,  hard...
# 31808  [adoracao,  brazilian gospel,  brazilian metal...
#
#                                              album_name  \
# 700                                           Mezmerize
# 43778                                    Lost and Found
# 722                                            Pop Evil
# 26161                                Evolution (Deluxe)
# 26150                                      Immortalized
# 26166             Ten Thousand Fists (Standard Edition)
# 17079                                    Brain Invaders
# 69641                                Modified Mortality
# 40283  Dr. Feelgood 20th Anniversary (Expanded Version)
# 31808                            Histórias e Bicicletas
#
#                                               track_href  \
# 700    https://api.spotify.com/v1/tracks/0EYOdF5FCkgO...
# 43778  https://api.spotify.com/v1/tracks/0INUE1K7cEiE...
# 722    https://api.spotify.com/v1/tracks/2mVFo8BJ6ZPh...
# 26161  https://api.spotify.com/v1/tracks/2xECSFHPgCyE...
# 26150  https://api.spotify.com/v1/tracks/34bimdZj8GMH...
# 26166  https://api.spotify.com/v1/tracks/4ClGNWLK9vZM...
# 17079  https://api.spotify.com/v1/tracks/2iFFcHvg5F7a...
# 69641  https://api.spotify.com/v1/tracks/6OJSwJnf500x...
# 40283  https://api.spotify.com/v1/tracks/5X0bLSho0KTi...
# 31808  https://api.spotify.com/v1/tracks/6cmAiMLCOqV1...
#
#                                              preview_url  \
# 700    https://p.scdn.co/mp3-preview/2f373f029e1110b1...
# 43778  https://p.scdn.co/mp3-preview/a4972554181a20b1...
# 722    https://p.scdn.co/mp3-preview/f430fee71dd2ef47...
# 26161  https://p.scdn.co/mp3-preview/40055a0e9aef53d4...
# 26150  https://p.scdn.co/mp3-preview/7200198474bd64db...
# 26166  https://p.scdn.co/mp3-preview/d829a0f99289b0e2...
# 17079  https://p.scdn.co/mp3-preview/9bdb08f7d16e27fc...
# 69641  https://p.scdn.co/mp3-preview/8f5e01102526b9c0...
# 40283  https://p.scdn.co/mp3-preview/c5eb3b91b3eb57c8...
# 31808  https://p.scdn.co/mp3-preview/b30146aa2b204b38...
#
#                                             analysis_url  \
# 700    https://api.spotify.com/v1/audio-analysis/0EYO...
# 43778  https://api.spotify.com/v1/audio-analysis/0INU...
# 722    https://api.spotify.com/v1/audio-analysis/2mVF...
# 26161  https://api.spotify.com/v1/audio-analysis/2xEC...
# 26150  https://api.spotify.com/v1/audio-analysis/34bi...
# 26166  https://api.spotify.com/v1/audio-analysis/4ClG...
# 17079  https://api.spotify.com/v1/audio-analysis/2iFF...
# 69641  https://api.spotify.com/v1/audio-analysis/6OJS...
# 40283  https://api.spotify.com/v1/audio-analysis/5X0b...
# 31808  https://api.spotify.com/v1/audio-analysis/6cmA...
#
#                                                     href  \
# 700    https://api.spotify.com/v1/tracks/0EYOdF5FCkgO...
# 43778  https://api.spotify.com/v1/tracks/0INUE1K7cEiE...
# 722    https://api.spotify.com/v1/tracks/2mVFo8BJ6ZPh...
# 26161  https://api.spotify.com/v1/tracks/2xECSFHPgCyE...
# 26150  https://api.spotify.com/v1/tracks/34bimdZj8GMH...
# 26166  https://api.spotify.com/v1/tracks/4ClGNWLK9vZM...
# 17079  https://api.spotify.com/v1/tracks/2iFFcHvg5F7a...
# 69641  https://api.spotify.com/v1/tracks/6OJSwJnf500x...
# 40283  https://api.spotify.com/v1/tracks/5X0bLSho0KTi...
# 31808  https://api.spotify.com/v1/tracks/6cmAiMLCOqV1...
#
#                                                   lyrics            playlist  \
# 700    \r\n\r\nYou!\r\nWhy do they always send the po...    Metal Essentials
# 43778  \r\nIn this hole\r\nThat is me\r\nThe dead are...    Metal Essentials
# 722    \r\nPull the trigger, ride the bull\r\nAnd cut...           Rock This
# 26161  \r\n\r\nOnce again we hear them calling for wa...    Heviä treeneihin
# 26150  \r\n\r\nYou're paralyzed\r\nBreathe your disgu...   Rock til arbejdet
# 26166  \r\n\r\nI must have dreamed a thousand dreams\...         Rock Covers
# 17079  \r\n\r\nTo all my friends who are just like me...   Punk Rock Workout
# 69641  \r\n\r\nOn the next level\r\nNext level\r\n\r\...              Sludge
# 40283  \r\n\r\nYeah yeah\r\nRat-tailed Jimmy is a sec...      ’80s Hard Rock
# 31808  \r\n\r\nEnquanto a mesa é servida e farta\r\nL...  This Is Oficina G3
#
#        ...  artists_followers  artists_artist_popularity  \
# 700    ...            4774393                         79
# 43778  ...             700048                         62
# 722    ...             270542                         63
# 26161  ...            2771476                         78
# 26150  ...            2771476                         78
# 26166  ...            2771476                         78
# 17079  ...             141967                         58
# 69641  ...              12440                         40
# 40283  ...            1615727                         70
# 31808  ...             328710                         53
#
#                    artists_id album_release_date  \
# 700    5eAWCfyUhZtHHtBdNk56l1         2005-05-17
# 43778  2Pfv2w8a20xzC7Dr7QXRqM         2005-01-01
# 722    1pRaG81GsVtaTBuVSpldt2         2018-02-16
# 26161  3TOqt5oJwL9BE2NG9MEwDa         2018-10-19
# 26150  3TOqt5oJwL9BE2NG9MEwDa         2015-08-21
# 26166  3TOqt5oJwL9BE2NG9MEwDa         2005-09-19
# 17079  6SiyKSeJo6gcsS2NvuAbsl         2019-03-06
# 69641  3Cnkej21cJ1XgbAh98CbaS         2018-08-02
# 40283  0cc6vw3VN8YlIcvr1v7tBL         1989-01-01
# 31808  0gO5Vbklho8yrBrUdHhuLH         2013-04-30
#
#                                             album_images  album_total_tracks  \
# 700    [{'height': 640, 'url': 'https://i.scdn.co/ima...                  11
# 43778  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  12
# 722    [{'height': 640, 'url': 'https://i.scdn.co/ima...                  11
# 26161  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  14
# 26150  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  13
# 26166  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  14
# 17079  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  15
# 69641  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  13
# 40283  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  16
# 31808  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  11
#
#                                      album_external_urls  \
# 700    {'spotify': 'https://open.spotify.com/album/0c...
# 43778  {'spotify': 'https://open.spotify.com/album/0d...
# 722    {'spotify': 'https://open.spotify.com/album/2z...
# 26161  {'spotify': 'https://open.spotify.com/album/1I...
# 26150  {'spotify': 'https://open.spotify.com/album/3q...
# 26166  {'spotify': 'https://open.spotify.com/album/0T...
# 17079  {'spotify': 'https://open.spotify.com/album/3J...
# 69641  {'spotify': 'https://open.spotify.com/album/3r...
# 40283  {'spotify': 'https://open.spotify.com/album/2r...
# 31808  {'spotify': 'https://open.spotify.com/album/4J...
#
#                      album_id     distances  match_genre_count
# 700    0cn6MHyx4YuZauaB7Pb66o  9.964058e-15                  7
# 43778  0dCRu5tVhx9fvbVZSxfjfP  4.152681e-01                  7
# 722    2zrUlKeTyEhyYulj8Gu8T9  5.672768e-01                  7
# 26161  1IpufqmucrxYUJQxf1AP0n  1.973208e-01                  6
# 26150  3qFQ4XNQ15alZrAaj5oGJK  5.486804e-01                  6
# 26166  0Te7OvzuUMnbsqCneIDUm6  5.568184e-01                  6
# 17079  3JKg0soC1sRle2yPenQa2j  5.461792e-01                  5
# 69641  3rL7hD0TxdEIpAkQ3WsZSj  5.237434e-01                  3
# 40283  2roIODnunU2CI0QWY3T8H9  5.321707e-01                  3
# 31808  4JQYqu6oRSh7pEj2YS4Ggc  5.697469e-01                  3
#
# [10 rows x 24 columns]
