# %% [markdown]
# ## Python Requirements

# %%
pip install pandas dagster dagit sklearn pickle streamlit streamlit-pandas

# %% [markdown]
# ## Dagster Home als Umgebungsvariable setzen

# %%
echo $DAGSTER_HOME "C:\Users\stefa\OneDrive - FHWN\Privat\Studium\MIT_2-Semester\Analyseanwendungen\spotify_recommender\etl.py"

# %% [markdown]
# ## Dagster starten

# %%
dagit -f etl.py
