# %%
# %%file spotify_rec.py

import os
import pandas as pd
import ast
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.neighbors import NearestNeighbors

workspacefolder = os.path.join('C:\\Users\\stefa\\OneDrive - FHWN\\Privat\\Studium\\MIT_2-Semester\\Analyseanwendungen\\spotify_recommender')


def str_to_list(s):
    s = str(s)[1:-1]
    if len(s) == 0:
        s = "'not defined'"
    items = s.split(',')
    return [item.replace("'","") for item in items]

# @op
def import_albums():
    albums_path = os.path.join(workspacefolder,'spotify_data/Data Sources/spotify_albums.csv')
    return pd.read_csv(albums_path,sep=',',index_col='Unnamed: 0').rename(columns=lambda x: "album_" + x)

# @op
def import_artists():
    albums_path = os.path.join(workspacefolder,'spotify_data/Data Sources/spotify_artists.csv')
    return pd.read_csv(albums_path,sep=',',index_col='Unnamed: 0').rename(columns=lambda x: "artists_" + x)

# @op
def import_tracks():
    albums_path = os.path.join(workspacefolder,'workspacefolder,spotify_data/Data Sources/spotify_tracks.csv')
    return pd.read_csv(albums_path,sep=',',index_col='Unnamed: 0').rename(columns={'id':'track_id','artists_id':'track_artists_id'})

def import_lyrics_features():
    albums_path = os.path.join(workspacefolder,'spotify_data/Features Extracted/lyrics_features.csv')
    df = pd.read_csv(albums_path,sep=',',index_col='Unnamed: 0')
    return df

def import_audio_features():
    albums_path = os.path.join(workspacefolder,'spotify_data/Features Extracted/low_level_audio_features.csv')
    df = pd.read_csv(albums_path,sep=',',index_col='Unnamed: 0')
    return df

# @op
def transform_albums(albums_raw):
    df = albums_raw.copy()
    df['album_available_markets'] = df['album_available_markets'].apply(lambda x: str_to_list(x))
    df['album_release_date'] = pd.to_datetime(df['album_release_date'])
    df['album_external_urls'] = df['album_external_urls'].apply(ast.literal_eval)
    df['album_images'] = df['album_images'].apply(ast.literal_eval)
    
    return df

def transform_artists(artists_raw):
    df = artists_raw.copy()
    df['artists_genres'] = df['artists_genres'].apply(lambda x: str_to_list(x))

    return df

def transform_tracks(tracks_raw):
    df = tracks_raw.copy()
    df['available_markets'] = df['available_markets'].apply(lambda x: str_to_list(x))
    df['track_artists_id'] = df['track_artists_id'].apply(lambda x: str_to_list(x))

    return df

# @op
def match_spotify_data(tracks,albums,artists):
    tracks = tracks.explode('track_artists_id') # tack zeile pro artist

    merged = pd.merge(tracks, albums, left_on='album_id', right_on='album_id', how='inner')
    return pd.merge(merged, artists, left_on='track_artists_id', right_on='artists_id', how='inner')
    #####x left -> 139878 rows × 53 columns
    # inner -> 101939 rows × 53 columns

    
def match_features(tracks_albums_artists,audio_features,lyrics_features): # match_spotify_data
    tracks_albums_artists_audio = pd.merge(tracks_albums_artists, audio_features, left_on='track_id', right_on='track_id', how='inner')
    tracks_albums_artists_audio_lyrics = pd.merge(tracks_albums_artists_audio, lyrics_features, left_on='track_id', right_on='track_id', how='inner')
    return tracks_albums_artists_audio_lyrics
    #####x left -> 128684 rows × 266 columns
    # inner -> 94924 rows × 266 columns

def track_info(df): # match_features
    df = df[['name','track_href','preview_url','analysis_url','href','lyrics','playlist','popularity','tempo','time_signature','track_id',
             'artists_name','artists_genres','artists_followers', 'artists_artist_popularity', 'artists_id',
             'album_name','album_release_date','album_images','album_total_tracks','album_external_urls','album_id']]
    return df

def normalize(series):
    return (series - series.min()) / (series.max() - series.min()) * 100



def extract_highlvl_features(tracks_albums_artists):
    df_h = tracks_albums_artists[['track_id','album_release_date','album_available_markets','artists_followers','artists_genres']].copy()
    df_h['album_release_date'] = df_h['album_release_date'].apply(lambda x: int(x.year))
    df_h['artists_followers_n'] = normalize(df_h['artists_followers'])
    df_h['artists_followers_category'] = pd.cut(df_h['artists_followers_n'],bins=10,labels=False)
    
    return df_h

def extract_lowlvl_features(matched_all):
    pass


def extract_features(df):
    features = ['acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 'valence'] + [f'Chroma_{i}' for i in range(1, 13)] + [f'MEL_{i}' for i in range(1, 129)] + [f'MFCC_{i}' for i in range(1, 49)] + [f'Spectral_contrast_{i}' for i in range(1, 8)] + [f'Tonnetz_{i}' for i in range(1, 7)] + ['ZCR', 'entropy_energy', 'spectral_bandwith', 'spectral_centroid', 'spectral_rollOff_max', 'spectral_rollOff_min']

    # Skalieren
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(df[features])

    # Bewerten -> Random Forest
    rf = RandomForestRegressor(n_estimators=100, random_state=42)
    rf.fit(scaled_data, df.index) # Hier verwenden wir `track_id` als Dummy-Ziel, da es bei der Feature-Auswahl nur um die Wichtigkeit der Features geht.

    # Wählen Sie Features aus, deren Wichtigkeit größer als der Durchschnitt ist
    sfm = SelectFromModel(rf, threshold='mean')
    sfm.fit(scaled_data, df.index)
    important_features = np.array(features)[sfm.get_support()]

    # Dimensionen reduzieren
    pca = PCA(n_components=0.95)  # Behalten Sie 95% der Varianz bei
    features = pca.fit_transform(scaled_data[:, sfm.get_support()])
    
    return features

# @op
def train_knn(features,k):
    knn = NearestNeighbors(n_neighbors=k)
    knn.fit(features)

    return knn

def predict_test(knn,row):
    distances, indices = knn.kneighbors(row.reshape(1, -1))


# @op
def save_spotify_data():
    pass
# @op
def save_knn():
    pass

# %% [markdown]
# eventuell genres cluster bilden und die genres dann filtern für den sogs cluster

# %%
albums = transform_albums(import_albums())
artists = transform_artists(import_artists())
tracks = transform_tracks(import_tracks())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 albums = transform_albums(import_albums())
#       2 artists = transform_artists(import_artists())
#       3 tracks = transform_tracks(import_tracks())
#
# Cell In[1], line 26, in import_albums()
#      24 def import_albums():
#      25     albums_path = os.path.join(workspacefolder,'spotify_data/Data Sources/spotify_albums.csv')
# ---> 26     return pd.read_csv(albums_path,sep=',',index_col='Unnamed: 0').rename(columns=lambda x: "album_" + x)
#
# File c:\ProgramData\Anaconda3\envs\Analyseanwendungen\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\ProgramData\Anaconda3\envs\Analyseanwendungen\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\ProgramData\Anaconda3\envs\Analyseanwendungen\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File c:\ProgramData\Anaconda3\envs\Analyseanwendungen\lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File c:\ProgramData\Anaconda3\envs\Analyseanwendungen\lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File c:\ProgramData\Anaconda3\envs\Analyseanwendungen\lib\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File c:\ProgramData\Anaconda3\envs\Analyseanwendungen\lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\stefa\\OneDrive - FHWN\\Privat\\Studium\\MIT_2-Semester\\Analyseanwendungen\\spotify_recommender\\spotify_data/Data Sources/spotify_albums.csv'

# %%
albums.head()
# albums.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 albums.head()
#
# NameError: name 'albums' is not defined

# %%
artists.head()
# Out:
#    artists_artist_popularity  artists_followers  \
# 0                         44              23230
# 1                         22                313
# 2                         26               1596
# 3                         31                149
# 4                         21                 11
#
#                                       artists_genres              artists_id  \
# 0  [sertanejo,  sertanejo pop,  sertanejo tradici...  4mGnpjhqgx4RUdsIJiURdo
# 1                                      [not defined]  1dLnVku4VQUOLswwDFvRc9
# 2                                  [danish pop rock]  6YVY310fjfUzKi8hiqR7iK
# 3                               [uk alternative pop]  2VElyouiCfoYPDJluzwJwK
# 4                                   [french baroque]  4agVy03qW8juSysCTUOuDI
#
#           artists_name        artists_track_id artists_track_name_prev  \
# 0        Juliano Cezar  0wmDmAILuW9e2aRttkl4aC                 track_9
# 1       The Grenadines  4wqwj0gA8qPZKLl5WVqXml                track_30
# 2              Gangway  1bFqWDbvHmZe2f4Nf9qaD8                track_38
# 3                FADES  3MFSUBAidPzRBbIS7BDj1S                track_34
# 4  Jean-Pierre Guignon  2r3q57FhxdsCyYr0kuDq4b                track_26
#
#   artists_type
# 0       artist
# 1       artist
# 2       artist
# 3       artist
# 4       artist

# %%
tracks#.head()
# tracks.columns.tolist()
# Out:
#         acousticness                album_id  \
# 0           0.294000  0D3QufeCudpQANOR7luqdr
# 1           0.863000  1bcqsH5UyTBzmh9YizdsBE
# 2           0.750000  4tKijjmxGClg4JOLAyo2qE
# 3           0.763000  6FeJF5r8roonnKraJxr4oB
# 4           0.770000  4tKijjmxGClg4JOLAyo2qE
# ...              ...                     ...
# 101934      0.005640  1M9n4vCmOH4lbcHrpt21Qy
# 101935      0.000406  511p6iaCuK8Sr0BYdpcfkq
# 101936      0.004510  511p6iaCuK8Sr0BYdpcfkq
# 101937      0.333000  7H3Bgvb3hs4vvLwccHDRlr
# 101938      0.028400  3oieBBYbUOve0VpxTCpHr1
#
#                                              analysis_url  \
# 0       https://api.spotify.com/v1/audio-analysis/5qlj...
# 1       https://api.spotify.com/v1/audio-analysis/3VAX...
# 2       https://api.spotify.com/v1/audio-analysis/1L3Y...
# 3       https://api.spotify.com/v1/audio-analysis/6aCe...
# 4       https://api.spotify.com/v1/audio-analysis/1Vo8...
# ...                                                   ...
# 101934  https://api.spotify.com/v1/audio-analysis/4e5w...
# 101935  https://api.spotify.com/v1/audio-analysis/58nH...
# 101936  https://api.spotify.com/v1/audio-analysis/2RDg...
# 101937  https://api.spotify.com/v1/audio-analysis/1pXt...
# 101938  https://api.spotify.com/v1/audio-analysis/6MzG...
#
#                 track_artists_id  \
# 0       xJuHRn2ZWD5OofvJtDZY]
# 1       [4xWMewm6CYMstu0sPgd9jJ]
# 2       [3hYaK5FF3YAglCj5HZgBnP]
# 3       [2KQsUB9DRBcJk17JWX1eXD]
# 4       [3hYaK5FF3YAglCj5HZgBnP]
# ...                          ...
# 101934  [6n3YUZcayLRuAunJUUelvz]
# 101935  [4iudEcmuPlYNdbP3e1bdn1]
# 101936  [4iudEcmuPlYNdbP3e1bdn1]
# 101937  [023YMawCG3OvACmRjWxLWC]
# 101938  [6OgAO7QYncP5feMijPxBxi]
#
#                                         available_markets country  \
# 0       [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...      BE
# 1       [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...      BE
# 2                                                    [GB]      BE
# 3       [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...      BE
# 4                                                    [GB]      BE
# ...                                                   ...     ...
# 101934                                          [AU,  NZ]      AR
# 101935  [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...      AR
# 101936  [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...      AR
# 101937  [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...      AR
# 101938  [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...      AR
#
#         danceability  disc_number  duration_ms  energy  ...  \
# 0              0.698          1.0     235584.0   0.606  ...
# 1              0.719          1.0     656960.0   0.308  ...
# 2              0.466          1.0     492840.0   0.931  ...
# 3              0.719          1.0     316578.0   0.126  ...
# 4              0.460          1.0     558880.0   0.942  ...
# ...              ...          ...          ...     ...  ...
# 101934         0.602          1.0     178893.0   0.904  ...
# 101935         0.177          1.0     213133.0   0.823  ...
# 101936         0.539          1.0     226107.0   0.883  ...
# 101937         0.716          1.0     224133.0   0.748  ...
# 101938         0.500          1.0     251787.0   0.869  ...
#
#                                               preview_url speechiness  \
# 0       https://p.scdn.co/mp3-preview/1b05a902da3a251d...      0.0262
# 1       https://p.scdn.co/mp3-preview/d8140736a6131cb5...      0.9220
# 2       https://p.scdn.co/mp3-preview/c8af28fb15185b18...      0.9440
# 3       https://p.scdn.co/mp3-preview/7629b8e9f31f6e9b...      0.9380
# 4       https://p.scdn.co/mp3-preview/32be593c0eb82868...      0.9430
# ...                                                   ...         ...
# 101934  https://p.scdn.co/mp3-preview/06f1c1e06ce801d5...      0.0327
# 101935  https://p.scdn.co/mp3-preview/c5a00b395106508f...      0.0604
# 101936  https://p.scdn.co/mp3-preview/128c860edbac0c6e...      0.0653
# 101937  https://p.scdn.co/mp3-preview/447bbc0bf9324173...      0.1510
# 101938  https://p.scdn.co/mp3-preview/c3d9e399a329d25d...      0.0324
#
#           tempo  time_signature  \
# 0       115.018             4.0
# 1       115.075             3.0
# 2        79.565             4.0
# 3       112.822             3.0
# 4        81.260             4.0
# ...         ...             ...
# 101934  130.186             4.0
# 101935  184.260             4.0
# 101936  118.043             4.0
# 101937  110.015             4.0
# 101938  139.749             4.0
#
#                                                track_href  track_name_prev  \
# 0       https://api.spotify.com/v1/tracks/5qljLQuKnNJf...         track_14
# 1       https://api.spotify.com/v1/tracks/3VAX2MJdmdqA...          track_3
# 2       https://api.spotify.com/v1/tracks/1L3YAhsEMrGV...          track_4
# 3       https://api.spotify.com/v1/tracks/6aCe9zzoZmCo...          track_9
# 4       https://api.spotify.com/v1/tracks/1Vo802A38tPF...          track_2
# ...                                                   ...              ...
# 101934  https://api.spotify.com/v1/tracks/4e5wI6VC4eVD...         track_10
# 101935  https://api.spotify.com/v1/tracks/58nHFSWj5N5J...         track_16
# 101936  https://api.spotify.com/v1/tracks/2RDgs05sg2vr...         track_21
# 101937  https://api.spotify.com/v1/tracks/1pXtUVmSS3Ak...         track_26
# 101938  https://api.spotify.com/v1/tracks/6MzG4xUhUHNL...         track_30
#
#        track_number                                   uri valence   type
# 0               1.0  spotify:track:5qljLQuKnNJf4F4vfxQB0V  0.6220  track
# 1               3.0  spotify:track:3VAX2MJdmdqARLSU5hPMpm  0.5890  track
# 2               4.0  spotify:track:1L3YAhsEMrGVvCgDXj2TYn  0.0850  track
# 3               1.0  spotify:track:6aCe9zzoZmCojX7bbgKKtf  0.5330  track
# 4               2.0  spotify:track:1Vo802A38tPFHmje1h91um  0.0906  track
# ...             ...                                   ...     ...    ...
# 101934          4.0  spotify:track:4e5wI6VC4eVDTtpyZ409Pw  0.7870  track
# 101935          7.0  spotify:track:58nHFSWj5N5JxNtWgS85TL  0.3630  track
# 101936          2.0  spotify:track:2RDgs05sg2vrpwiAEUkWd0  0.4060  track
# 101937          5.0  spotify:track:1pXtUVmSS3Aky3j6nQ4sQT  0.7600  track
# 101938          9.0  spotify:track:6MzG4xUhUHNLZBe3RAC2cX  0.6410  track
#
# [101939 rows x 31 columns]

# %% [markdown]
# ## Match Data

# %%
lyrics_features = import_lyrics_features()
# lyrics_features.dtypes
lyrics_features.head()
# Out:
#    mean_syllables_word  mean_words_sentence  n_sentences  n_words  \
# 0                -1.00                -1.00           -1       -1
# 1                 1.10                 5.65           31      326
# 2                 1.37                 4.77           74      532
# 3                 1.95                 3.38           72      430
# 4                 1.16                 2.99           68      368
#
#    sentence_similarity                track_id  vocabulary_wealth
# 0            -1.000000  5KIfHjHI5NIsPHNt58qua0              -1.00
# 1             0.043011  13keyz9ikBe6ZpRasw7l4X               0.45
# 2             0.050352  1WugzepXsLjnsM0K4UaWYc               0.59
# 3             0.028560  2MO6oEAlMKcsfI8xP3yoy8               0.49
# 4             0.047849  1i4St7fmSUE9nB3R9n8fol               0.47

# %%
audio_features = import_audio_features()
# audio_features.dtypes
audio_features.head()
# Out:
#    Chroma_1  Chroma_10  Chroma_11  Chroma_12  Chroma_2  Chroma_3  Chroma_4  \
# 0  0.438296   0.472769   0.427441   0.436688  0.467697  0.493862  0.512244
# 1  0.596605   0.368288   0.285263   0.302211  0.905805  0.510909  0.221708
# 2  0.505224   0.500420   0.506773   0.488258  0.498356  0.573582  0.690761
# 3  0.525690   0.666469   0.579492   0.498920  0.598528  0.631578  0.501693
# 4  0.632214   0.503698   0.496942   0.611532  0.634613  0.697265  0.557012
#
#    Chroma_5  Chroma_6  Chroma_7  ...  Tonnetz_4  Tonnetz_5  Tonnetz_6  \
# 0  0.568658  0.560524  0.513068  ...   0.018434  -0.001759  -0.006392
# 1  0.311248  0.491277  0.416469  ...   0.046941   0.005665  -0.026928
# 2  0.742858  0.686282  0.657118  ...  -0.006929   0.004968   0.008947
# 3  0.500468  0.587101  0.546499  ...  -0.027382  -0.009689   0.001402
# 4  0.530836  0.444279  0.466659  ...   0.003728  -0.002780  -0.010120
#
#         ZCR  entropy_energy  spectral_bandwith  spectral_centroid  \
# 0  0.067966      -89.113389        2564.247669        3558.400706
# 1  0.047308     -127.945239        2370.181495        1499.689590
# 2  0.058463     -238.285176        2973.294736        1543.550034
# 3  0.080547     -148.785733        2716.749483        3017.248824
# 4  0.084945     -176.618314        3096.692876        2118.686992
#
#    spectral_rollOff_max  spectral_rollOff_min                track_id
# 0           4508.506071            367.831109  19YEk4OVQZn3GfoxbpNrU6
# 1           3647.394611            230.165275  6zJms3MX11Qu1IKF44LoRW
# 2           5623.349330            187.290534  1WugzepXsLjnsM0K4UaWYc
# 3           5799.931595            160.940693  1pSlTbCrUJ9rmwj5CNNrX4
# 4           6560.018666            229.131948  5yruvWJs3mL00w4slpCVzN
#
# [5 rows x 208 columns]

# %%
matched_all = match_spotify_data(tracks,albums,artists,audio_features,lyrics_features)
matched_all
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 matched_all = match_spotify_data(tracks,albums,artists,audio_features,lyrics_features)
#       2 matched_all
#
# NameError: name 'tracks' is not defined

# %%
info = track_info(matched_all)
info
# Out:
#                                                     name  \
# 0                                                  Blood
# 1                                                Jericho
# 2                                      The Ugly Duckling
# 3                                          My Little Dog
# 4                                       Three Blind Mice
# ...                                                  ...
# 94919                                            Kind of
# 94920  Light Flex (From the Original Motion Picture S...
# 94921                                      Coffeebreak 2
# 94922                                       From The Sea
# 94923                        Black Fingernails, Red Wine
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/5qljLQuKnNJf...
# 1      https://api.spotify.com/v1/tracks/3THTkAwJOsmx...
# 2      https://api.spotify.com/v1/tracks/3VAX2MJdmdqA...
# 3      https://api.spotify.com/v1/tracks/7rT11H4kU8yi...
# 4      https://api.spotify.com/v1/tracks/1WJzRtI1ABzV...
# ...                                                  ...
# 94919  https://api.spotify.com/v1/tracks/4Wd44BDoB1kO...
# 94920  https://api.spotify.com/v1/tracks/2c07bc2mwRIc...
# 94921  https://api.spotify.com/v1/tracks/4L820y58kEWk...
# 94922  https://api.spotify.com/v1/tracks/1GR1U3xkN1gf...
# 94923  https://api.spotify.com/v1/tracks/0ujklxrVM2jw...
#
#                                              preview_url  \
# 0      https://p.scdn.co/mp3-preview/1b05a902da3a251d...
# 1      https://p.scdn.co/mp3-preview/8af517b8202114d6...
# 2      https://p.scdn.co/mp3-preview/d8140736a6131cb5...
# 3      https://p.scdn.co/mp3-preview/6abd2c72a2d7ced7...
# 4      https://p.scdn.co/mp3-preview/54031f6d3ab4784a...
# ...                                                  ...
# 94919  https://p.scdn.co/mp3-preview/0c8a81c00f7efec2...
# 94920  https://p.scdn.co/mp3-preview/43584f38e1fef0a8...
# 94921  https://p.scdn.co/mp3-preview/918a32baa3a0fb08...
# 94922  https://p.scdn.co/mp3-preview/fe5686b36f1e0c24...
# 94923  https://p.scdn.co/mp3-preview/bace770dd8c0e8fd...
#
#                                             analysis_url  \
# 0      https://api.spotify.com/v1/audio-analysis/5qlj...
# 1      https://api.spotify.com/v1/audio-analysis/3THT...
# 2      https://api.spotify.com/v1/audio-analysis/3VAX...
# 3      https://api.spotify.com/v1/audio-analysis/7rT1...
# 4      https://api.spotify.com/v1/audio-analysis/1WJz...
# ...                                                  ...
# 94919  https://api.spotify.com/v1/audio-analysis/4Wd4...
# 94920  https://api.spotify.com/v1/audio-analysis/2c07...
# 94921  https://api.spotify.com/v1/audio-analysis/4L82...
# 94922  https://api.spotify.com/v1/audio-analysis/1GR1...
# 94923  https://api.spotify.com/v1/audio-analysis/0ujk...
#
#                                                     href  \
# 0      https://api.spotify.com/v1/tracks/5qljLQuKnNJf...
# 1      https://api.spotify.com/v1/tracks/3THTkAwJOsmx...
# 2      https://api.spotify.com/v1/tracks/3VAX2MJdmdqA...
# 3      https://api.spotify.com/v1/tracks/7rT11H4kU8yi...
# 4      https://api.spotify.com/v1/tracks/1WJzRtI1ABzV...
# ...                                                  ...
# 94919  https://api.spotify.com/v1/tracks/4Wd44BDoB1kO...
# 94920  https://api.spotify.com/v1/tracks/2c07bc2mwRIc...
# 94921  https://api.spotify.com/v1/tracks/4L820y58kEWk...
# 94922  https://api.spotify.com/v1/tracks/1GR1U3xkN1gf...
# 94923  https://api.spotify.com/v1/tracks/0ujklxrVM2jw...
#
#                                                   lyrics  \
# 0      \r\n\r\nPerhaps I am bound to be restless\r\nA...
# 1      \r\n\r\nMuch better in my day\r\nMuch better i...
# 2      \r\nYour Gods and my Gods-do you or I know whi...
# 3      \r\nYour Gods and my Gods-do you or I know whi...
# 4      \r\nYour Gods and my Gods-do you or I know whi...
# ...                                                  ...
# 94919  \r\n\r\nUh, Boss Don shit\r\n(Coke Boy, baby)\...
# 94920  \r\n\r\nShe want, I want, we want it, yeah, ye...
# 94921  \r\n\r\nShe want, I want, we want it, yeah, ye...
# 94922  \r\nOoh I'm so spaced out today\r\nOoh I could...
# 94923  \r\n\r\nBlack Fingernails, red wine\r\nI wanna...
#
#                           playlist  popularity    tempo  time_signature  ...  \
# 0                  Hipsteribrunssi        28.0  115.018             4.0  ...
# 1                    Sideways 2019        37.0  139.876             3.0  ...
# 2                   Animal Stories        31.0  115.075             3.0  ...
# 3                   Animal Stories         0.0  109.748             5.0  ...
# 4                   Animal Stories         0.0   77.056             3.0  ...
# ...                            ...         ...      ...             ...  ...
# 94919                 Slay All Day         8.0   99.986             4.0  ...
# 94920                 Slay All Day        39.0  110.068             4.0  ...
# 94921                 Slay All Day         7.0  120.009             4.0  ...
# 94922  Aussie Alternative Classics        53.0  129.880             4.0  ...
# 94923  Aussie Alternative Classics        54.0  123.974             4.0  ...
#
#                                           artists_genres artists_followers  \
# 0                                        [finnish indie]               425
# 1                                        [finnish indie]               425
# 2                                          [not defined]              2965
# 3                                          [not defined]              2965
# 4                                          [not defined]              2965
# ...                                                  ...               ...
# 94919                                         [sky room]              1198
# 94920  [alternative r&b,  deep pop r&b,  indie r&b,  ...             26892
# 94921                                [icelandic hip hop]               585
# 94922  [australian alternative rock,  australian indi...             59326
# 94923  [australian alternative rock,  australian indi...             59326
#
#       artists_artist_popularity              artists_id  \
# 0                            28  3mxJuHRn2ZWD5OofvJtDZY
# 1                            28  3mxJuHRn2ZWD5OofvJtDZY
# 2                            36  4xWMewm6CYMstu0sPgd9jJ
# 3                            36  4xWMewm6CYMstu0sPgd9jJ
# 4                            36  4xWMewm6CYMstu0sPgd9jJ
# ...                         ...                     ...
# 94919                        37  6Nva7JhU0nL9SZ8ZvJni6O
# 94920                        52  756t7CBmWLNYsshVtS6P44
# 94921                        16  6viUqm7m1tI9x3EIo0dTLR
# 94922                        47  3yW6jTzGjHUUkLvLkjLOVn
# 94923                        47  3yW6jTzGjHUUkLvLkjLOVn
#
#                                               album_name album_release_date  \
# 0                                                  Blood         2018-05-18
# 1                                                Jericho         2019-01-25
# 2                             Storytime Classics, Vol. 2         2011-03-01
# 3                             Storytime Classics, Vol. 2         2011-03-01
# 4                             Storytime Classics, Vol. 1         2011-03-01
# ...                                                  ...                ...
# 94919                                            Kind of         2018-06-22
# 94920  Light Flex (From the Original Motion Picture S...         2018-04-27
# 94921                                            BIZNESS         2018-11-09
# 94922                                   A Song Is A City         2004-01-01
# 94923                        Black Fingernails, Red Wine         2006-06-10
#
#                                             album_images album_total_tracks  \
# 0      [{'height': 600, 'url': 'https://i.scdn.co/ima...                  2
# 1      [{'height': 600, 'url': 'https://i.scdn.co/ima...                  1
# 2      [{'height': 640, 'url': 'https://i.scdn.co/ima...                 13
# 3      [{'height': 640, 'url': 'https://i.scdn.co/ima...                 13
# 4      [{'height': 640, 'url': 'https://i.scdn.co/ima...                 13
# ...                                                  ...                ...
# 94919  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  1
# 94920  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  1
# 94921  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  7
# 94922  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 12
# 94923  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 13
#
#                                      album_external_urls  \
# 0      {'spotify': 'https://open.spotify.com/album/0D...
# 1      {'spotify': 'https://open.spotify.com/album/3w...
# 2      {'spotify': 'https://open.spotify.com/album/1b...
# 3      {'spotify': 'https://open.spotify.com/album/1b...
# 4      {'spotify': 'https://open.spotify.com/album/51...
# ...                                                  ...
# 94919  {'spotify': 'https://open.spotify.com/album/0J...
# 94920  {'spotify': 'https://open.spotify.com/album/1R...
# 94921  {'spotify': 'https://open.spotify.com/album/3j...
# 94922  {'spotify': 'https://open.spotify.com/album/3q...
# 94923  {'spotify': 'https://open.spotify.com/album/4P...
#
#                      album_id
# 0      0D3QufeCudpQANOR7luqdr
# 1      3wIjGVauUxR4c3NvnQZ0Jo
# 2      1bcqsH5UyTBzmh9YizdsBE
# 3      1bcqsH5UyTBzmh9YizdsBE
# 4      51g5viCaYjOW5XO4qX1RCD
# ...                       ...
# 94919  0JsX1vzGzf0RNCAcBHhO1X
# 94920  1RKcmHPNIjZVAaXklTOPjO
# 94921  3jKce9NvEDsYPGOqMsWzko
# 94922  3qUUxffTYleIODTFlc2CXh
# 94923  4PXy3cBCNeY0ZVKTOGi9Cw
#
# [94924 rows x 22 columns]

# %% [markdown]
# ## Extract Features
#
# #### Idee 1:
# 2 Ebenen:
# - Grobes Clustering
#   - artists_genre
#   - release_date
#   - artists_followers
#   - ...
#
# - Feines Clustering
#   - ... audio features

# %%
# Genre cluster
tracks_albums_artists[['name','artists_name','album_release_date','album_album_type','album_available_markets','album_type','artists_followers','artists_genres','artists_type']]
# Out:
#                                                      name  \
# 0                                                   Blood
# 1                                                 Jericho
# 2                                       The Ugly Duckling
# 3                                           My Little Dog
# 4                                        Three Blind Mice
# ...                                                   ...
# 101934                                            Kind of
# 101935  Light Flex (From the Original Motion Picture S...
# 101936                                      Coffeebreak 2
# 101937                                       From The Sea
# 101938                        Black Fingernails, Red Wine
#
#                  artists_name album_release_date album_album_type  \
# 0                Jesse Markin         2018-05-18           single
# 1                Jesse Markin         2019-01-25           single
# 2       Favorite Kids Stories         2011-03-01            album
# 3       Favorite Kids Stories         2011-03-01            album
# 4       Favorite Kids Stories         2011-03-01            album
# ...                       ...                ...              ...
# 101934               Tom Enzy         2018-06-22           single
# 101935             Tone Stith         2018-04-27           single
# 101936                  CYBER         2018-11-09            album
# 101937             Eskimo Joe         2004-01-01            album
# 101938             Eskimo Joe         2006-06-10            album
#
#                                   album_available_markets album_type  \
# 0       [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...      album
# 1       [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...      album
# 2       [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...      album
# 3       [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...      album
# 4       [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...      album
# ...                                                   ...        ...
# 101934  [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...      album
# 101935  [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...      album
# 101936  [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...      album
# 101937  [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...      album
# 101938                                          [AU,  NZ]      album
#
#         artists_followers                                     artists_genres  \
# 0                     425                                    [finnish indie]
# 1                     425                                    [finnish indie]
# 2                    2965                                      [not defined]
# 3                    2965                                      [not defined]
# 4                    2965                                      [not defined]
# ...                   ...                                                ...
# 101934               1198                                         [sky room]
# 101935              26892  [alternative r&b,  deep pop r&b,  indie r&b,  ...
# 101936                585                                [icelandic hip hop]
# 101937              59326  [australian alternative rock,  australian indi...
# 101938              59326  [australian alternative rock,  australian indi...
#
#        artists_type
# 0            artist
# 1            artist
# 2            artist
# 3            artist
# 4            artist
# ...             ...
# 101934       artist
# 101935       artist
# 101936       artist
# 101937       artist
# 101938       artist
#
# [101939 rows x 9 columns]

# %%
for i in tracks_albums_artists.columns.tolist():
    if i.startswith('album') or i.startswith('artist'):
        print(i)
# Out:
# album_id
# album_album_type
# album_artist_id
# album_available_markets
# album_external_urls
# album_href
# album_images
# album_name
# album_release_date
# album_release_date_precision
# album_total_tracks
# album_track_id
# album_track_name_prev
# album_uri
# album_type
# artists_artist_popularity
# artists_followers
# artists_genres
# artists_id
# artists_name
# artists_track_id
# artists_track_name_prev
# artists_type

# %%
tracks_albums_artists.columns.tolist()
# Out:
# ['acousticness',
#  'album_id',
#  'analysis_url',
#  'track_artists_id',
#  'available_markets',
#  'country',
#  'danceability',
#  'disc_number',
#  'duration_ms',
#  'energy',
#  'href',
#  'track_id',
#  'instrumentalness',
#  'key',
#  'liveness',
#  'loudness',
#  'lyrics',
#  'mode',
#  'name',
#  'playlist',
#  'popularity',
#  'preview_url',
#  'speechiness',
#  'tempo',
#  'time_signature',
#  'track_href',
#  'track_name_prev',
#  'track_number',
#  'uri',
#  'valence',
#  'type',
#  'album_album_type',
#  'album_artist_id',
#  'album_available_markets',
#  'album_external_urls',
#  'album_href',
#  'album_images',
#  'album_name',
#  'album_release_date',
#  'album_release_date_precision',
#  'album_total_tracks',
#  'album_track_id',
#  'album_track_name_prev',
#  'album_uri',
#  'album_type',
#  'artists_artist_popularity',
#  'artists_followers',
#  'artists_genres',
#  'artists_id',
#  'artists_name',
#  'artists_track_id',
#  'artists_track_name_prev',
#  'artists_type']

# %%
# for i in audio_features.columns.tolist():
#     if not i.startswith('MEL'):
#         print(i)

lyrics_features.columns.tolist()
# Out:
# ['mean_syllables_word',
#  'mean_words_sentence',
#  'n_sentences',
#  'n_words',
#  'sentence_similarity',
#  'track_id',
#  'vocabulary_wealth']

# %%
# audio cluster
tracks_albums_artists[['acousticness','danceability']]
# Out:
#         acousticness  danceability
# 0            0.29400         0.698
# 1            0.16600         0.543
# 2            0.86300         0.719
# 3            0.82400         0.752
# 4            0.82400         0.688
# ...              ...           ...
# 101934       0.00840         0.751
# 101935       0.23200         0.765
# 101936       0.03550         0.782
# 101937       0.10000         0.587
# 101938       0.00837         0.553
#
# [101939 rows x 2 columns]

# %%
features = extract_highlvl_features(matched_all)
features.sort_values('artists_followers_n')
# Out:
#                      track_id  album_release_date  \
# 69284  4Hvzc1phamhnrwQVVTR0VA                2019
# 32113  4mLF1i7DYL9amWUCEb4qQf                2017
# 43316  6VTYMRDqFFFHjzKtrjRCKL                2018
# 58879  747m1y1zgIyfWBGOcRDFe5                2019
# 10656  3G3qLFFcPo4khWwE1AwrJO                2019
# ...                       ...                 ...
# 14744  1VdZ0vKfR5jneCmWIUAMxK                2011
# 14745  3SZLtkoHoECHHuOnNkNCuS                2014
# 14746  0AOvD8LrdeDVDaLzSB7YsM                2018
# 14747  66qlqxhEMpSHOzjRK4il0b                2017
# 14759  1dVWoeam7D1Zg6hB57pBE7                2017
#
#                                  album_available_markets  artists_followers  \
# 69284  [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...                  0
# 32113  [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...                  0
# 43316  [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...                  0
# 58879  [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...                  0
# 10656  [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...                  0
# ...                                                  ...                ...
# 14744  [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...           41561693
# 14745  [AD,  AE,  AR,  BE,  BG,  BH,  BO,  BR,  CA,  ...           41561693
# 14746  [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...           41561693
# 14747  [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...           41561693
# 14759  [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...           41561693
#
#        artists_genres  artists_followers_n  artists_followers_category
# 69284   [not defined]                  0.0                           0
# 32113   [not defined]                  0.0                           0
# 43316   [not defined]                  0.0                           0
# 58879   [not defined]                  0.0                           0
# 10656   [not defined]                  0.0                           0
# ...               ...                  ...                         ...
# 14744  [pop,  uk pop]                100.0                           9
# 14745  [pop,  uk pop]                100.0                           9
# 14746  [pop,  uk pop]                100.0                           9
# 14747  [pop,  uk pop]                100.0                           9
# 14759  [pop,  uk pop]                100.0                           9
#
# [94924 rows x 7 columns]

# %%
# features = extract_features(df=matched_all)
# knn = train_knn(features,5)

# %%
# predict_test(knn,features[0])

# %% [markdown]
# ## Dagster
#
# http://localhost:3000

# %%
cd C:\Users\stefa\OneDrive - FHWN\Privat\Studium\MIT_2-Semester\Analyseanwendungen\spotify_recommender
dagit -f etl.py
# Out:
#   Cell In[6], line 1
#     cd 'C:\Users\stefa\OneDrive - FHWN\Privat\Studium\MIT_2-Semester\Analyseanwendungen\spotify_recommender'
#        ^
# SyntaxError: invalid syntax

# %%
from datetime import datetime

datetime.now().strftime('%Y-%m-%d')
# Out:
# '2023-05-18'

# %%
import os
import pandas as pd
import ast
import pickle
from datetime import datetime

workspacefolder = os.path.join('C:\\Users\\stefa\\OneDrive - FHWN\\Privat\\Studium\\MIT_2-Semester\\Analyseanwendungen\\spotify_recommender')

def str_to_list(s):
    s = str(s)[1:-1]
    if len(s) == 0:
        s = "'not defined'"
    items = s.split(',')
    return [item.replace("'","") for item in items]


def import_albums():
    albums_path = os.path.join(workspacefolder,'spotify_data/Data Sources/spotify_albums.csv')
    return pd.read_csv(albums_path,sep=',',index_col='Unnamed: 0').rename(columns=lambda x: "album_" + x)

def import_artists():
    albums_path = os.path.join(workspacefolder,'spotify_data/Data Sources/spotify_artists.csv')
    return pd.read_csv(albums_path,sep=',',index_col='Unnamed: 0').rename(columns=lambda x: "artists_" + x)

def import_tracks():
    albums_path = os.path.join(workspacefolder,'spotify_data/Data Sources/spotify_tracks.csv')
    return pd.read_csv(albums_path,sep=',',index_col='Unnamed: 0').rename(columns={'id':'track_id','artists_id':'track_artists_id'})

def import_lyrics_features():
    albums_path = os.path.join(workspacefolder,'spotify_data/Features Extracted/lyrics_features.csv')
    df = pd.read_csv(albums_path,sep=',',index_col='Unnamed: 0')
    return df

def import_audio_features():
    albums_path = os.path.join(workspacefolder,'spotify_data/Features Extracted/low_level_audio_features.csv')
    df = pd.read_csv(albums_path,sep=',',index_col='Unnamed: 0')
    return df


def transform_albums(albums_raw):
    df = albums_raw.copy()
    df['album_available_markets'] = df['album_available_markets'].apply(lambda x: str_to_list(x))
    df['album_release_date'] = pd.to_datetime(df['album_release_date'])
    df['album_external_urls'] = df['album_external_urls'].apply(ast.literal_eval)
    df['album_images'] = df['album_images'].apply(ast.literal_eval)
    
    return df


def transform_artists(artists_raw):
    df = artists_raw.copy()
    df['artists_genres'] = df['artists_genres'].apply(lambda x: str_to_list(x))

    return df


def transform_tracks(tracks_raw):
    df = tracks_raw.copy()
    df['available_markets'] = df['available_markets'].apply(lambda x: str_to_list(x))
    df['track_artists_id'] = df['track_artists_id'].apply(lambda x: str_to_list(x))

    return df


def match_spotify_data(tracks,albums,artists,audio_features,lyrics_features):
    # tracks = tracks.explode('track_artists_id') # tack zeile pro artist

    merged = pd.merge(tracks, albums, left_on='album_id', right_on='album_id', how='inner')
    tracks_albums_artists = pd.merge(merged, artists, left_on='track_artists_id', right_on='artists_id', how='inner')
    # inner -> 101939 rows × 53 columns

    tracks_albums_artists_audio = pd.merge(tracks_albums_artists, audio_features, left_on='track_id', right_on='track_id', how='inner')
    tracks_albums_artists_audio_lyrics = pd.merge(tracks_albums_artists_audio, lyrics_features, left_on='track_id', right_on='track_id', how='inner')
    # inner -> 94924 rows × 266 columns

    return tracks_albums_artists_audio_lyrics
    


def track_info(df): # match_features
    df = df[['name','track_href','preview_url','analysis_url','href','lyrics','playlist','popularity','tempo','time_signature','track_id',
             'artists_name','artists_genres','artists_followers', 'artists_artist_popularity', 'artists_id',
             'album_name','album_release_date','album_images','album_total_tracks','album_external_urls','album_id']]
    return df


def save_pickl(model,name='model'):
    filename = f"{datetime.now().strftime('%Y-%m-%d')}_{name}.pickle"
    with open(filename,'wb') as f:
        f.dump(model,f)


def prepare_dataset():
    albums = transform_albums(import_albums())
    artists = transform_artists(import_artists())
    tracks = transform_tracks(import_tracks())
    lyrics_features = import_lyrics_features()
    audio_features = import_audio_features()
    data = match_spotify_data(tracks,albums,artists,audio_features,lyrics_features)
    return data


# def prepare_infos(df = prepare_dataset()):
#     track_infos = track_info(df)

#     save_pickl(track_infos,'track_info')

# %%
# data = prepare_dataset()
# data

import etl_nodagster2 as etl
data = etl.prepare_dataset()
data
# Out:
#        acousticness                album_id  \
# 0           0.29400  0D3QufeCudpQANOR7luqdr
# 1           0.16600  3wIjGVauUxR4c3NvnQZ0Jo
# 2           0.86300  1bcqsH5UyTBzmh9YizdsBE
# 3           0.82400  1bcqsH5UyTBzmh9YizdsBE
# 4           0.82400  51g5viCaYjOW5XO4qX1RCD
# ...             ...                     ...
# 94919       0.00840  0JsX1vzGzf0RNCAcBHhO1X
# 94920       0.23200  1RKcmHPNIjZVAaXklTOPjO
# 94921       0.03550  3jKce9NvEDsYPGOqMsWzko
# 94922       0.10000  3qUUxffTYleIODTFlc2CXh
# 94923       0.00837  4PXy3cBCNeY0ZVKTOGi9Cw
#
#                                             analysis_url  \
# 0      https://api.spotify.com/v1/audio-analysis/5qlj...
# 1      https://api.spotify.com/v1/audio-analysis/3THT...
# 2      https://api.spotify.com/v1/audio-analysis/3VAX...
# 3      https://api.spotify.com/v1/audio-analysis/7rT1...
# 4      https://api.spotify.com/v1/audio-analysis/1WJz...
# ...                                                  ...
# 94919  https://api.spotify.com/v1/audio-analysis/4Wd4...
# 94920  https://api.spotify.com/v1/audio-analysis/2c07...
# 94921  https://api.spotify.com/v1/audio-analysis/4L82...
# 94922  https://api.spotify.com/v1/audio-analysis/1GR1...
# 94923  https://api.spotify.com/v1/audio-analysis/0ujk...
#
#              track_artists_id  \
# 0      3mxJuHRn2ZWD5OofvJtDZY
# 1      3mxJuHRn2ZWD5OofvJtDZY
# 2      4xWMewm6CYMstu0sPgd9jJ
# 3      4xWMewm6CYMstu0sPgd9jJ
# 4      4xWMewm6CYMstu0sPgd9jJ
# ...                       ...
# 94919  6Nva7JhU0nL9SZ8ZvJni6O
# 94920  756t7CBmWLNYsshVtS6P44
# 94921  6viUqm7m1tI9x3EIo0dTLR
# 94922  3yW6jTzGjHUUkLvLkjLOVn
# 94923  3yW6jTzGjHUUkLvLkjLOVn
#
#                                        available_markets country  \
# 0      [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...      BE
# 1      [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...      AR
# 2      [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...      BE
# 3      [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...      BE
# 4      [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...      BE
# ...                                                  ...     ...
# 94919  [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...      AR
# 94920  [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...      AR
# 94921  [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...      AR
# 94922  [AD,  AE,  AR,  AT,  AU,  BE,  BG,  BH,  BO,  ...      AR
# 94923                                          [AU,  NZ]      AR
#
#        danceability  disc_number  duration_ms  energy  ... spectral_bandwith  \
# 0             0.698          1.0     235584.0   0.606  ...       2571.486199
# 1             0.543          1.0     233998.0   0.612  ...       2841.629117
# 2             0.719          1.0     656960.0   0.308  ...       2091.303337
# 3             0.752          1.0      27960.0   0.338  ...       1842.085802
# 4             0.688          1.0      29240.0   0.304  ...       2054.925010
# ...             ...          ...          ...     ...  ...               ...
# 94919         0.751          1.0     214800.0   0.785  ...       4044.576961
# 94920         0.765          1.0     232640.0   0.864  ...       3317.130571
# 94921         0.782          1.0     220878.0   0.665  ...       2812.649623
# 94922         0.587          1.0     202907.0   0.786  ...       3292.071115
# 94923         0.553          1.0     251253.0   0.907  ...       2875.836603
#
#       spectral_centroid  spectral_rollOff_max  spectral_rollOff_min  \
# 0           2087.112746           4485.181212            131.157540
# 1           2332.188831           5376.300824            136.132510
# 2           1353.341469           3686.694374            416.947479
# 3           4127.629407           2996.190129            354.667677
# 4           2593.912948           3762.130116            469.926469
# ...                 ...                   ...                   ...
# 94919       5860.747427           8515.715173            130.690876
# 94920       3572.375183           6603.935067            311.781448
# 94921       2121.388838           4961.070001            271.273360
# 94922       2734.479304           6342.186650            191.557175
# 94923       3067.500963           5053.552775            139.924154
#
#        mean_syllables_word  mean_words_sentence n_sentences  n_words  \
# 0                     1.39                 3.13          39      208
# 1                     1.25                 2.67          81      363
# 2                     1.44                25.56         106     5106
# 3                     1.44                25.56         106     5106
# 4                     1.44                25.56         106     5106
# ...                    ...                  ...         ...      ...
# 94919                 1.16                 4.89         103      907
# 94920                 1.20                 4.34          67      452
# 94921                 1.20                 4.34          67      452
# 94922                 1.34                 3.42          31      178
# 94923                 1.24                 2.53          83      284
#
#       sentence_similarity vocabulary_wealth
# 0                0.028340              0.64
# 1                0.349074              0.16
# 2                0.000180              0.57
# 3                0.000180              0.57
# 4                0.000180              0.57
# ...                   ...               ...
# 94919            0.049686              0.53
# 94920            0.046585              0.35
# 94921            0.046585              0.35
# 94922            0.092473              0.42
# 94923            0.088158              0.47
#
# [94924 rows x 266 columns]

# %%
import pandas as pd
import numpy as np
import pickle
import time
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.neighbors import NearestNeighbors


class SpotifyRecommender:
    supported = ['acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 'valence'] + [f'Chroma_{i}' for i in range(1, 13)] + [f'MEL_{i}' for i in range(1, 129)] + [f'MFCC_{i}' for i in range(1, 49)] + [f'Spectral_contrast_{i}' for i in range(1, 8)] + [f'Tonnetz_{i}' for i in range(1, 7)] + ['ZCR', 'entropy_energy', 'spectral_bandwith', 'spectral_centroid', 'spectral_rollOff_max', 'spectral_rollOff_min']
    def __init__(self,dataset,features=supported,k=20):
        self.scaler = None
        self.pca = None
        self.sfm = None
        self.knn = None
        self.k = k
        self.filepath = None
        self.dataset = dataset
        self.features = []
        self.get_features(dataset,features)

    def get_features(self,data,features):
        listed = data.columns.tolist()
        for f in listed:
            if f in self.supported and f in features:
                self.features.append(f)


    def train(self):

        self.scaler = StandardScaler()
        scaled_data = self.scaler.fit_transform(self.dataset[self.features])

        rf = RandomForestRegressor(n_estimators=100, random_state=42)
        rf.fit(scaled_data, self.dataset.index)  # Hier verwende ich data.index anstelle von target

        self.sfm = SelectFromModel(rf, threshold='mean')
        self.sfm.fit(scaled_data, self.dataset.index)  # Hier verwende ich data.index anstelle von target

        self.pca = PCA(n_components=0.95)
        reduced_data = self.pca.fit_transform(scaled_data[:, self.sfm.get_support()])

        self.knn = NearestNeighbors(n_neighbors=self.k)
        self.knn.fit(reduced_data)

    def predict(self, track_id):
        new_data = self.dataset[self.dataset['track_id']==track_id]
        new_scaled_data = self.scaler.transform(new_data[self.features])
        new_reduced_data = self.pca.transform(new_scaled_data[:, self.sfm.get_support()])
        distances, indices = self.knn.kneighbors(new_reduced_data)
        
        return self.dataset.iloc[indices[0]]#, distances, indices

    def save(self, file_path=None):
        if file_path == None:
            file_path = self.filepath
        model_data = {
            'knn': self.knn,
            'scaler': self.scaler,
            'pca': self.pca,
            'sfm': self.sfm,
            'filepath': file_path,
            'features': self.features
        }
        with open(file_path, 'wb') as f:
            pickle.dump(model_data, f)

    def load(self, file_path):
        with open(file_path, 'rb') as f:
            model_data = pickle.load(f)

        self.knn = model_data['knn']
        self.scaler = model_data['scaler']
        self.pca = model_data['pca']
        self.sfm = model_data['sfm']
        self.filepath = model_data['file_path']
        self.features =  model_data['features']

# %%
features = ['acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'speechiness', 'tempo', 'time_signature']

model = SpotifyRecommender(data)#,features)
# model.dataset
model.train()

# %%
model.save(f"evaluation\\SpotifyRecommenderV2.pickle")

# %%
# Bring Me The Horizon
# System Of A Down
data[data['artists_name'] == 'System Of A Down'][['track_id','name','artists_name','artists_genres']]
# data['artists_name'].unique().tolist()
# Out:
#                    track_id         name      artists_name  \
# 696  6oO7WMjD6kEvCITLbVj0mu    Hypnotize  System Of A Down
# 697  1VNWaY3uNfoeWqb5U8x2QX   Lonely Day  System Of A Down
# 698  1Ym3JWJG8HFJU2NbXavZ6a        Sugar  System Of A Down
# 699  41pOIT2t1rvr2Trg1HQChZ  Radio/Video  System Of A Down
# 700  0EYOdF5FCkgOJJla8DI2Md     B.Y.O.B.  System Of A Down
# 701  7cWBlhe7dt3nHipbII25m1        Sugar  System Of A Down
# 702  1qGmxIGEuBEkj7bft72Kh0    Suite-Pee  System Of A Down
# 703  4e9eGQYsOiBcftrWXwsVco      Aerials  System Of A Down
# 704  0snQkGI5qnAmohLE7jTsTn     Toxicity  System Of A Down
# 705  2DlHlPMa4M17kufBvI2lEN   Chop Suey!  System Of A Down
# 706  7kwiwQhWRBSP1PJv4ZFJUK   Chop Suey!  System Of A Down
#
#                                         artists_genres
# 696  [alternative metal,  nu metal,  post-grunge,  ...
# 697  [alternative metal,  nu metal,  post-grunge,  ...
# 698  [alternative metal,  nu metal,  post-grunge,  ...
# 699  [alternative metal,  nu metal,  post-grunge,  ...
# 700  [alternative metal,  nu metal,  post-grunge,  ...
# 701  [alternative metal,  nu metal,  post-grunge,  ...
# 702  [alternative metal,  nu metal,  post-grunge,  ...
# 703  [alternative metal,  nu metal,  post-grunge,  ...
# 704  [alternative metal,  nu metal,  post-grunge,  ...
# 705  [alternative metal,  nu metal,  post-grunge,  ...
# 706  [alternative metal,  nu metal,  post-grunge,  ...

# %%
out = model.predict('0EYOdF5FCkgOJJla8DI2Md')
out[['name','artists_name','album_name','artists_genres']]
# Out:
#                                       name          artists_name  \
# 700                               B.Y.O.B.      System Of A Down
# 699                            Radio/Video      System Of A Down
# 682                                   Rise             Sixx:A.M.
# 685                                   Rise             Sixx:A.M.
# 663                         American Idiot             Green Day
# 666                         American Idiot             Green Day
# 720                    Deal with the Devil              Pop Evil
# 662                             Homecoming             Green Day
# 704                               Toxicity      System Of A Down
# 506                    Livin' la Vida Loca          Ricky Martin
# 636                       Revolution Radio             Green Day
# 665   Holiday / Boulevard of Broken Dreams             Green Day
# 714                                 Divide              Pop Evil
# 610                            Drown - New  Bring Me The Horizon
# 802                                BURN IT             FEVER 333
# 639                        Still Breathing             Green Day
# 697                             Lonely Day      System Of A Down
# 1688                  Quiero Verte Sonreir          Carlos Vives
# 723                           Waking Lions              Pop Evil
# 1270         Love Has All Been Done Before             Jade Bird
#
#                          album_name  \
# 700                       Mezmerize
# 699                       Mezmerize
# 682          Prayers for the Damned
# 685                            Rise
# 663         American Idiot (Deluxe)
# 666                  American Idiot
# 720                            Onyx
# 662         American Idiot (Deluxe)
# 704                        Toxicity
# 506                    Ricky Martin
# 636                Revolution Radio
# 665                  American Idiot
# 714                   Onyx (Deluxe)
# 610               That's The Spirit
# 802           STRENGTH IN NUMB333RS
# 639                Revolution Radio
# 697                       Hypnotize
# 1688                  Déjame Entrar
# 723                        Pop Evil
# 1270  Love Has All Been Done Before
#
#                                          artists_genres
# 700   [alternative metal,  nu metal,  post-grunge,  ...
# 699   [alternative metal,  nu metal,  post-grunge,  ...
# 682   [alternative metal,  nu metal,  post-grunge,  ...
# 685   [alternative metal,  nu metal,  post-grunge,  ...
# 663           [permanent wave,  pop punk,  punk,  rock]
# 666           [permanent wave,  pop punk,  punk,  rock]
# 720   [alternative metal,  nu metal,  post-grunge,  ...
# 662           [permanent wave,  pop punk,  punk,  rock]
# 704   [alternative metal,  nu metal,  post-grunge,  ...
# 506   [dance pop,  latin,  latin pop,  mexican pop, ...
# 636           [permanent wave,  pop punk,  punk,  rock]
# 665           [permanent wave,  pop punk,  punk,  rock]
# 714   [alternative metal,  nu metal,  post-grunge,  ...
# 610    [melodic metalcore,  metalcore,  rock,  screamo]
# 802                                       [not defined]
# 639           [permanent wave,  pop punk,  punk,  rock]
# 697   [alternative metal,  nu metal,  post-grunge,  ...
# 1688  [champeta,  colombian pop,  dance pop,  latin,...
# 723   [alternative metal,  nu metal,  post-grunge,  ...
# 1270                                     [uk americana]
