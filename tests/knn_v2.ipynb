# %%
best_features = ['acousticness','danceability','duration_ms','energy','instrumentalness',
                            'liveness','loudness','speechiness','tempo','valence','Chroma_1',
                            'Chroma_2','Chroma_3','Chroma_4','Chroma_5','Chroma_6','Chroma_7',
                            'Chroma_8','Chroma_9','Chroma_10','Chroma_11','Chroma_12','MEL_1','MEL_2',
                            'MEL_3','MEL_4','MEL_5','MEL_6','MEL_7','MEL_8','MEL_13','MEL_14',
                            'MEL_16','MEL_17','MEL_18','MEL_19','MEL_20','MEL_22','MEL_23','MEL_24',
                            'MEL_27','MEL_30','MEL_51','MFCC_2','MFCC_3','MFCC_4','MFCC_5','MFCC_6',
                            'MFCC_7','MFCC_8','MFCC_9','MFCC_10','MFCC_11','MFCC_12','MFCC_13',
                            'MFCC_14','MFCC_15','MFCC_16','MFCC_17','MFCC_18','MFCC_19','MFCC_20',
                            'MFCC_21','MFCC_22','MFCC_23','MFCC_24','MFCC_25','MFCC_26','MFCC_27',
                            'MFCC_28','MFCC_29','MFCC_30','MFCC_31','MFCC_32','MFCC_33','MFCC_34',
                            'MFCC_35','MFCC_36','MFCC_37','MFCC_38','MFCC_39','MFCC_40','MFCC_41',
                            'MFCC_42','MFCC_43','MFCC_44','MFCC_45','MFCC_46','MFCC_47','MFCC_48',
                            'Spectral_contrast_1','Spectral_contrast_2','Spectral_contrast_3',
                            'Spectral_contrast_4','Spectral_contrast_5','Spectral_contrast_6',
                            'Spectral_contrast_7','Tonnetz_1','Tonnetz_2','Tonnetz_3','Tonnetz_4',
                            'Tonnetz_5','Tonnetz_6','entropy_energy','spectral_centroid',
                            'spectral_rollOff_min']

# %%
import pandas as pd
import numpy as np
import pickle
import time
import os
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.neighbors import NearestNeighbors


class SpotifyRecommender:
    supported = ['acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 'valence'] + [f'Chroma_{i}' for i in range(1, 13)] + [f'MEL_{i}' for i in range(1, 129)] + [f'MFCC_{i}' for i in range(1, 49)] + [f'Spectral_contrast_{i}' for i in range(1, 8)] + [f'Tonnetz_{i}' for i in range(1, 7)] + ['ZCR', 'entropy_energy', 'spectral_bandwith', 'spectral_centroid', 'spectral_rollOff_max', 'spectral_rollOff_min']
    return_columns = ['name','artists_name','artists_genres','album_name','track_href','preview_url','analysis_url','href','lyrics','playlist','popularity','tempo','time_signature','track_id',
             'artists_followers', 'artists_artist_popularity', 'artists_id','album_release_date','album_images','album_total_tracks','album_external_urls','album_id']
    def __init__(self,load_model="",k=20):
        self.scaler = None
        self.pca = None
        self.sfm = None
        self.knn = None
        self.k = k
        self.filepath = 'saved_modelV2.pkl'
        self.dataset = None
        self.trained_features = []
        if not load_model == "":
            path = os.path.join(load_model)
            self.load(path)
        

    def get_features(self,data,features):
        listed = data.columns.tolist()
        for f in listed:
            if f in self.supported and f in features:
                self.trained_features.append(f)
        return


    def train(self,dataset,n_lines=0,features=supported):
        self.get_features(dataset,features)
        self.dataset = dataset

        if not n_lines == 0:
            dataset = dataset.sample(n=n_lines)

        self.scaler = StandardScaler()
        scaled_data = self.scaler.fit_transform(dataset[self.trained_features])

        rf = RandomForestRegressor(n_estimators=100, random_state=42)
        rf.fit(scaled_data, dataset.index)  # Hier verwende ich data.index anstelle von target

        self.sfm = SelectFromModel(rf, threshold='mean')
        self.sfm.fit(scaled_data, dataset.index)  # Hier verwende ich data.index anstelle von target

        self.pca = PCA(n_components=0.95)
        reduced_data = self.pca.fit_transform(scaled_data[:, self.sfm.get_support()])

        self.knn = NearestNeighbors(n_neighbors=self.k)
        self.knn.fit(reduced_data)

    def predict(self, df_selected,k=None):
        if not k==None:
            self.knn.n_neighbors = k

        new_scaled_data = self.scaler.transform(df_selected[self.trained_features])
        new_reduced_data = self.pca.transform(new_scaled_data[:, self.sfm.get_support()])
        distances, indices = self.knn.kneighbors(new_reduced_data)
        
        self.knn.n_neighbors = self.k
        return self.dataset[self.return_columns].iloc[indices[0]]#, distances, indices

    def save(self, file_path=None):
        if file_path == None:
            file_path = self.filepath
        model_data = {
            'knn': self.knn,
            'scaler': self.scaler,
            'pca': self.pca,
            'sfm': self.sfm,
            'dataset': self.dataset,
            'filepath': file_path,
            'trained_features': self.trained_features
        }
        with open(file_path, 'wb') as f:
            pickle.dump(model_data, f)

    def load(self, file_path):
        with open(file_path, 'rb') as f:
            model_data = pickle.load(f)

        self.knn = model_data['knn']
        self.scaler = model_data['scaler']
        self.pca = model_data['pca']
        self.sfm = model_data['sfm']
        self.filepath = model_data['filepath']
        self.trained_features =  model_data['trained_features']
        self.dataset = model_data['dataset']

# %%
import tests.etl_test as etl
data = etl.prepare_dataset()
data

# %%
features = ['acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'speechiness', 'tempo', 'time_signature']
model = SpotifyRecommender()

model.train(data, 5000, best_features)

# %%
model.save('modelV2_5000_best.pkl')

# %%
model2 = SpotifyRecommender()
model2.load('modelV2_5000_best.pkl')

# %%
pred = data[data['track_id']=='0EYOdF5FCkgOJJla8DI2Md']
pred[['name','artists_name','album_name','artists_genres']]
# Out:
#          name      artists_name album_name  \
# 700  B.Y.O.B.  System Of A Down  Mezmerize
#
#                                         artists_genres
# 700  [alternative metal,  nu metal,  post-grunge,  ...

# %%
model2.predict(pred)
# Out:
#                                                    name  \
# 1820                          In My Craft or Sullen Art
# 2781                                     Flores em Vida
# 4453                             Benjamin Blümchen Lied
# 2329  Symphony No. 5 in B-Flat Major; WAB 105: I. In...
# 3055                                              Outro
# 2236  Divertimento in F Major, K. 138, "Salzburg Sym...
# 4528                             Benjamin Blümchen Lied
# 4067            Pretty Shining People - Jack Wins Remix
# 1018                                      Feel Good Inc
# 4593     Kapitel 11: Der Dinosaurierknochen (Folge 139)
# 4790                                        El mariachi
# 981                                 Que viva el América
# 4562     Kapitel 11: Weihnachtsmarkt im Zoo (Folge 140)
# 4201                               On a Turquoise Cloud
# 2772                                         Pão de Mel
# 3177                                              Aicha
# 40                                     Archie, Marry Me
# 1170                                                 Sí
# 2997                          Act 1: The Speech (Greed)
# 2363                 Paranoid - 2009 Remastered Version
#
#                          artists_name  \
# 1820                     Dylan Thomas
# 2781        Zezé Di Camargo & Luciano
# 4453                Benjamin Blümchen
# 2329                   Anton Bruckner
# 3055                    Hank Schrader
# 2236          Wolfgang Amadeus Mozart
# 4528                Benjamin Blümchen
# 4067                      George Ezra
# 1018                         Gorillaz
# 4593                Benjamin Blümchen
# 4790                     Lola Beltrán
# 981   Claudio Yarto / Ricardo Treviño
# 4562                Benjamin Blümchen
# 4201                  Echoes of Swing
# 2772        Zezé Di Camargo & Luciano
# 3177                          Oh Land
# 40                            Alvvays
# 1170                    Martin Jensen
# 2997                           Borgus
# 2363                    Black Sabbath
#
#                                          artists_genres  \
# 1820                                           [poetry]
# 2781  [axe,  pagode,  sertanejo,  sertanejo universi...
# 4453                                        [hoerspiel]
# 2329                    [classical,  late romantic era]
# 3055                                      [not defined]
# 2236                        [classical,  classical era]
# 4528                                        [hoerspiel]
# 4067                      [neo-singer-songwriter,  pop]
# 1018             [alternative hip hop,  art pop,  rock]
# 4593                                        [hoerspiel]
# 4790                     [bolero,  mariachi,  ranchera]
# 981                                       [not defined]
# 4562                                        [hoerspiel]
# 4201                                      [not defined]
# 2772  [axe,  pagode,  sertanejo,  sertanejo universi...
# 3177                        [electropop,  metropopolis]
# 40    [art pop,  folk-pop,  indie pop,  indie psych-...
# 1170  [big room,  dance pop,  edm,  electro house,  ...
# 2997                                      [not defined]
# 2363  [album rock,  classic rock,  hard rock,  metal...
#
#                                              album_name  \
# 1820  Pleasure Dome: Audible Modern Poetry Read by i...
# 2781                                    Teorias de Raul
# 4453                    Folge 116: und die Spaßmaschine
# 2329                         Bruckner: Symphonies 5 & 9
# 3055                                       Breaking Bad
# 2236                        Mozart: Salzburg Symphonies
# 4528         Folge 141: Nachts in der Erfinderwerkstatt
# 4067            Pretty Shining People (Jack Wins Remix)
# 1018                                         Demon Days
# 4593                  Folge 139: Der Dinosaurierknochen
# 4790                           ¡Ay! Jalisco no te rajes
# 981                          América - Alzando el Vuelo
# 4562                  Folge 140: Weihnachtsmarkt im Zoo
# 4201                                          Travelin'
# 2772                Zezé Di Camargo & Luciano 1995-1996
# 3177                              Toppen Af Poppen 2015
# 40                                              Alvvays
# 1170                                                 Sí
# 2997                                     Not From Space
# 2363                 Paranoid (2009 Remastered Version)
#
#                                              track_href  \
# 1820  https://api.spotify.com/v1/tracks/56NEH1rR3mF8...
# 2781  https://api.spotify.com/v1/tracks/0yUFfbx9lqaw...
# 4453  https://api.spotify.com/v1/tracks/3ovv4gzs9Z03...
# 2329  https://api.spotify.com/v1/tracks/1tza7D25joES...
# 3055  https://api.spotify.com/v1/tracks/64pYZR9UjaO5...
# 2236  https://api.spotify.com/v1/tracks/76zEx8txhROE...
# 4528  https://api.spotify.com/v1/tracks/6j3YTWlfxifq...
# 4067  https://api.spotify.com/v1/tracks/5KsdfLLbAknc...
# 1018  https://api.spotify.com/v1/tracks/0d28khcov6Ai...
# 4593  https://api.spotify.com/v1/tracks/1IVwFTXKVqcl...
# 4790  https://api.spotify.com/v1/tracks/3g6J25NHJP3m...
# 981   https://api.spotify.com/v1/tracks/2m63qBGG1Q5i...
# 4562  https://api.spotify.com/v1/tracks/6RqW0WWgdKXu...
# 4201  https://api.spotify.com/v1/tracks/1XrEY8nz2P4L...
# 2772  https://api.spotify.com/v1/tracks/4NfBpnDF6JfN...
# 3177  https://api.spotify.com/v1/tracks/4EDMFXU6Ww1X...
# 2329  https://api.spotify.com/v1/tracks/1tza7D25joES...
# 3055  https://api.spotify.com/v1/tracks/64pYZR9UjaO5...
# 2236  https://api.spotify.com/v1/tracks/76zEx8txhROE...
# 4528  https://api.spotify.com/v1/tracks/6j3YTWlfxifq...
# 4067  https://api.spotify.com/v1/tracks/5KsdfLLbAknc...
# 1018  https://api.spotify.com/v1/tracks/0d28khcov6Ai...
# 4593  https://api.spotify.com/v1/tracks/1IVwFTXKVqcl...
# 4790  https://api.spotify.com/v1/tracks/3g6J25NHJP3m...
# 981   https://api.spotify.com/v1/tracks/2m63qBGG1Q5i...
# 4562  https://api.spotify.com/v1/tracks/6RqW0WWgdKXu...
# 4201  https://api.spotify.com/v1/tracks/1XrEY8nz2P4L...
# 2772  https://api.spotify.com/v1/tracks/4NfBpnDF6JfN...
# 3177  https://api.spotify.com/v1/tracks/4EDMFXU6Ww1X...
# 40    https://api.spotify.com/v1/tracks/5HLes17mwCwK...
# 1170  https://api.spotify.com/v1/tracks/279At8lP0zS4...
# 2997  https://api.spotify.com/v1/tracks/16JScjn1bvqd...
# 2363  https://api.spotify.com/v1/tracks/1jzDzZWeSDBg...
#
#                                                  lyrics  \
# 1820  \r\nIn my craft or sullen art\r\nExercised in ...
# 2781  \r\n\r\n(Christmas)\r\nThe snow's coming down\...
# 4453  \r\nAuf ner schönen grünen Wiese liegt ein gro...
# 2329                                                -99
# 3055  \r\nOut in the West Texas town of El Paso\r\nI...
# 2236                                                -99
# 4528  \r\nAuf ner schönen grünen Wiese liegt ein gro...
# 4067  \r\n\r\nAlright\r\nAlright\r\n\r\nMe and Sam i...
# 1018  \r\n\r\nHahahahahahahahahahahahahahahahaha, Fe...
# 4593  \r\nAuf ner schönen grünen Wiese liegt ein gro...
# 4790  \r\nAY !, JALISCO, JALISCO, JALISCO\r\nTU TIEN...
# 981   \r\nFiesta en América, fiesta en América\r\nFi...
# 4562  \r\nAuf ner schönen grünen Wiese liegt ein gro...
# 4201                                                -99
# 2772  \r\n\r\n(Christmas)\r\nThe snow's coming down\...
# 3177  \r\nSo sweet, so beautiful\r\nEveryday like a ...
# 40    \r\n\r\nYou've expressed explicitly your conte...
# 1170                 \r\n\r\nForza el fútbol\r\nSí!\r\n
# 2997  \r\nANNOUNCER: The Columbia Broadcasting Syste...
# 2363  \r\n\r\nI've exposed your lies, baby\r\nThe un...
#
#                                playlist  ...  time_signature  \
# 1820                      Modern Poetry  ...             4.0
# 2781  This Is Zezé Di Camargo & Luciano  ...             4.0
# 4453       Spaß mit Freunden: Hörspiele  ...             4.0
# 2329            Klassische Meisterwerke  ...             4.0
# 3055                       Breaking Bad  ...             0.0
# 2236                    Classical Feast  ...             3.0
# 4528    Hörspielzeit: Benjamin Blümchen  ...             4.0
# 4067                  Beats of Tomorrow  ...             4.0
# 1018                  Top Gaming Tracks  ...             4.0
# 4593    Hörspielzeit: Benjamin Blümchen  ...             3.0
# 4790           Narcos Mexico Soundtrack  ...             4.0
# 981                    Clásico Nacional  ...             4.0
# 4562    Hörspielzeit: Benjamin Blümchen  ...             5.0
[{'height': 640, 'url': 'https://i.scdn.co/ima...                 25
# 2781  [{'height': 576, 'url': 'https://i.scdn.co/ima...                 16
# 4453  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 39
# 2329  [{'height': 576, 'url': 'https://i.scdn.co/ima...                  7
# 3055  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 11
# 2236  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 14
# 4528  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 26
# 4067  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  1
# 1018  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 15
# 4593  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 29
# 4790  [{'height': 634, 'url': 'https://i.scdn.co/ima...                 14
# 981   [{'height': 640, 'url': 'https://i.scdn.co/ima...                 14
# 4562  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 28
# 4201  [{'height': 600, 'url': 'https://i.scdn.co/ima...                 15
# 2772  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 14
# 3177  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 42
# 40    [{'height': 640, 'url': 'https://i.scdn.co/ima...                  9
# 1170  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  1
# 2997  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  5
# 2363  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  8
#
#                                     album_external_urls  \
# 1820  {'spotify': 'https://open.spotify.com/album/6T...
# 2781  {'spotify': 'https://open.spotify.com/album/5b...
# 4453  {'spotify': 'https://open.spotify.com/album/52...
# 2329  {'spotify': 'https://open.spotify.com/album/0Z...
# 3055  {'spotify': 'https://open.spotify.com/album/6m...
# 2236  {'spotify': 'https://open.spotify.com/album/3l...
# 4528  {'spotify': 'https://open.spotify.com/album/4j...
# 4067  {'spotify': 'https://open.spotify.com/album/07...
# 1018  {'spotify': 'https://open.spotify.com/album/0b...
# 4593  {'spotify': 'https://open.spotify.com/album/4q...
# 4790  {'spotify': 'https://open.spotify.com/album/3Q...
# 981   {'spotify': 'https://open.spotify.com/album/6W...
# 4562  {'spotify': 'https://open.spotify.com/album/5q...
# 4201  {'spotify': 'https://open.spotify.com/album/6p...
# 2772  {'spotify': 'https://open.spotify.com/album/4o...
# 3177  {'spotify': 'https://open.spotify.com/album/4p...
# 40    {'spotify': 'https://open.spotify.com/album/4P...
# 1170  {'spotify': 'https://open.spotify.com/album/0q...
# 2997  {'spotify': 'https://open.spotify.com/album/7A...
# 2363  {'spotify': 'https://open.spotify.com/album/13...
#
#                     album_id
# 1820  6TTA2pOc7mXC5Wp2BlZvea
# 2781  5btZGpiPTfOVX1cmKbrbE4
# 4453  52BYCPzRCmDSRd7mkZkXYU
# 2329  0Z16Rbsc0amjDVKcSnP4WI
# 3055  6m50xHFiTuQc9xrJzbueEz
# 2236  3lZKH6rrfJrFwgHmW3B6LX
# 4528  4jxT7kNMkxJTrvI5nTY7RS
# 4067  07YRBa8JGxQC3pCTOSQxzE
# 1018  0bUTHlWbkSQysoM3VsWldT
# 4593  4qQbfYDSaexEwY7dI95qMi
# 4790  3Qzi3YK8CfKSFyAr46uAYK
# 981   6WuklW48vNEeUm2ebkIL2B
# 4562  5qpOBsGa2q0Ok59f46ebw5
# 4201  6pOPaRqCpE0X8aJN1lvXD5
# 2772  4ovUd8MXzvSA4sjipcETPh
# 3177  4pbxf5zOQ8eX996npW7jhW
# 40    4PrBMzWzzoMOwm55Bfo3dt
# 1170  0qxmg1d1Dpw2TFIoITs8W6
# 2997  7ACHe9LEWNdSWEoB6G33E2
# 2363  132qAo1cDiEJdA3fv4xyNK
#
# [20 rows x 22 columns]
